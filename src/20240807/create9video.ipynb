# %%
val_z = "../../output/20240807/output_video/val_z"
input_dirs = [
    "../../output/20240807/val_z/3.0/vae/5e-4/chk9/lightning_logs/version_0",
    "../../output/20240807/val_z/5.0/vae/5e-4/chk9/lightning_logs/version_0",
    "../../output/20240807/val_z/7.0/vae/5e-4/chk9/lightning_logs/version_0",
    "../../output/20240807/val_z/3.0/vae/1e-4/chk9/lightning_logs/version_1", 
    "../../output/20240807/val_z/5.0/vae/1e-4/chk9/lightning_logs/version_0",
    "../../output/20240807/val_z/7.0/vae/1e-4/chk9/lightning_logs/version_0",
    "../../output/20240807/val_z/[3.0]/vae/1e-5/chk9/lightning_logs/version_0",
    "../../output/20240807/val_z/[5.0]/vae/1e-5/chk9/lightning_logs/version_0",
    "../../output/20240807/val_z/[7.0]/vae/1e-5/chk9/lightning_logs/version_1",
]
output_dir = "../../output/20240807/output_video/val_z"

# %%
input_dirs = [
    "../../output/20240807/val_z/1.0/vae/5e-4/chk9/lightning_logs/version_0",
    "../../output/20240807/val_z/3.0/vae/5e-4/chk9/lightning_logs/version_0",
    "../../output/20240807/val_z/5.0/vae/5e-4/chk9/lightning_logs/version_0",
    "../../output/20240807/val_z/7.0/vae/5e-4/chk9/lightning_logs/version_0",
    "../../output/20240807/val_z/1.0/vae/1e-5/chk9/lightning_logs/version_0",
    "../../output/20240807/val_z/3.0/vae/1e-5/chk9/lightning_logs/version_0",
    "../../output/20240807/val_z/5.0/vae/1e-5/chk9/lightning_logs/version_0",
    "../../output/20240807/val_z/7.0/vae/1e-5/chk9/lightning_logs/version_0",
]
output_dir = "../../output/20240807/output_video/val_z"

# %%
input_dirs = [
    "../../output/20240807/val_unsplash20k_sunrise/1.0/vae/5e-4/chk9/lightning_logs/version_0",
    "../../output/20240807/val_unsplash20k_sunrise/3.0/vae/5e-4/chk9/lightning_logs/version_0",
    "../../output/20240807/val_unsplash20k_sunrise/5.0/vae/5e-4/chk9/lightning_logs/version_0",
    "../../output/20240807/val_unsplash20k_sunrise/7.0/vae/5e-4/chk9/lightning_logs/version_0",
    "../../output/20240807/val_unsplash20k_sunrise/1.0/vae/1e-5/chk9/lightning_logs/version_0",
    "../../output/20240807/val_unsplash20k_sunrise/3.0/vae/1e-5/chk9/lightning_logs/version_0",
    "../../output/20240807/val_unsplash20k_sunrise/5.0/vae/1e-5/chk9/lightning_logs/version_0",
    "../../output/20240807/val_unsplash20k_sunrise/7.0/vae/1e-5/chk9/lightning_logs/version_0",
]
output_dir = "../../output/20240807/output_video/sunrise"

# %%
import os
import shutil

# %%
for idx, source_dir in enumerate(input_dirs):
    frame_dir = source_dir + "/" + f"frame"
    crop_dir = source_dir + "/" +f"crop_image"
    print("---------------------------------")
    print(f"{crop_dir}")
    print("---------------------------------")
    os.makedirs(frame_dir, exist_ok=True)
    for i in range(60):
        shutil.copy(f"{crop_dir}/{i:05d}_{i:05d}.png", f"{frame_dir}/{i:05d}.png")
    if os.path.exists(f"{output_dir}/{idx:02d}.mp4"):
        os.remove(f"{output_dir}/{idx:02d}.mp4")
    os.system(f'ffmpeg -r 6 -i "{frame_dir}/%05d.png" -c:v libx264 -crf 12 -pix_fmt yuv420p {output_dir}/{idx:02d}.mp4')
# Out:
# ---------------------------------
# ../../output/20240807/val_unsplash20k_sunrise/1.0/vae/5e-4/chk9/lightning_logs/version_0/crop_image
# ---------------------------------
# ffmpeg version 4.4.2-0ubuntu0.22.04.1 Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 11 (Ubuntu 11.2.0-19ubuntu1)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.22.04.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libdav1d --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librabbitmq --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libsrt --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzimg --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-pocketsphinx --enable-librsvg --enable-libmfx --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared
#   libavutil      56. 70.100 / 56. 70.100
#   libavcodec     58.134.100 / 58.134.100
#   libavformat    58. 76.100 / 58. 76.100
#   libavdevice    58. 13.100 / 58. 13.100
#   libavfilter     7.110.100 /  7.110.100
#   libswscale      5.  9.100 /  5.  9.100
#   libswresample   3.  9.100 /  3.  9.100
#   libpostproc    55.  9.100 / 55.  9.100
# Input #0, image2, from '../../output/20240807/val_unsplash20k_sunrise/1.0/vae/5e-4/chk9/lightning_logs/version_0/frame/%05d.png':
#   Duration: 00:00:02.40, start: 0.000000, bitrate: N/A
#   Stream #0:0: Video: png, rgb24(pc), 512x512, 25 fps, 25 tbr, 25 tbn, 25 tbc
# Stream mapping:
#   Stream #0:0 -> #0:0 (png (native) -> h264 (libx264))
# Press [q] to stop, [?] for help
# [libx264 @ 0x55e3976d7800] using cpu capabilities: MMX2 SSE2Fast SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2
# [libx264 @ 0x55e3976d7800] profile High, level 2.2, 4:2:0, 8-bit
# [libx264 @ 0x55e3976d7800] 264 - core 163 r3060 5db6aa6 - H.264/MPEG-4 AVC codec - Copyleft 2003-2021 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=-2 threads=16 lookahead_threads=2 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=6 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=crf mbtree=1 crf=12.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to '../../output/20240807/output_video/sunrise/00.mp4':
#   Metadata:
#     encoder         : Lavf58.76.100
#   Stream #0:0: Video: h264 (avc1 / 0x31637661), yuv420p(tv, progressive), 512x512, q=2-31, 6 fps, 12288 tbn
#     Metadata:
#       encoder         : Lavc58.134.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: N/A
# frame=   60 fps=0.0 q=-1.0 Lsize=     954kB time=00:00:09.50 bitrate= 822.2kbits/s speed=30.6x
# video:952kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.158793%
# [libx264 @ 0x55e3976d7800] frame I:1     Avg QP: 5.73  size:209798
# [libx264 @ 0x55e3976d7800] frame P:22    Avg QP: 7.52  size: 32717
# [libx264 @ 0x55e3976d7800] frame B:37    Avg QP:14.70  size:  1205
# [libx264 @ 0x55e3976d7800] consecutive B-frames: 13.3% 10.0% 10.0% 66.7%
# [libx264 @ 0x55e3976d7800] mb I  I16..4:  6.1% 25.3% 68.7%
# [libx264 @ 0x55e3976d7800] mb P  I16..4:  0.0%  0.0%  0.0%  P16..4: 78.2%  5.3%  9.5%  0.0%  0.0%    skip: 6.9%
# [libx264 @ 0x55e3976d7800] mb B  I16..4:  0.0%  0.0%  0.0%  B16..8: 32.2%  1.3%  0.5%  direct: 0.8%  skip:65.2%  L0:48.0% L1:46.0% BI: 6.0%
# [libx264 @ 0x55e3976d7800] 8x8 transform intra:25.3% inter:42.6%
# [libx264 @ 0x55e3976d7800] coded y,uvDC,uvAC intra: 99.8% 99.9% 99.9% inter: 35.0% 13.8% 13.3%
# [libx264 @ 0x55e3976d7800] i16 v,h,dc,p: 31%  8% 37% 24%
# [libx264 @ 0x55e3976d7800] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu: 32% 10% 15%  6%  5% 10%  5% 10%  8%
# [libx264 @ 0x55e3976d7800] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 29%  8% 10%  6%  8% 11%  7% 12%  9%
# [libx264 @ 0x55e3976d7800] i8c dc,h,v,p: 54% 10% 27%  9%
# [libx264 @ 0x55e3976d7800] Weighted P-Frames: Y:0.0% UV:0.0%
# [libx264 @ 0x55e3976d7800] ref P L0: 76.8%  2.9% 13.8%  6.6%
# [libx264 @ 0x55e3976d7800] ref B L0: 58.3% 32.3%  9.3%
# [libx264 @ 0x55e3976d7800] ref B L1: 89.1% 10.9%
# [libx264 @ 0x55e3976d7800] kb/s:779.33
# ---------------------------------
# ../../output/20240807/val_unsplash20k_sunrise/3.0/vae/5e-4/chk9/lightning_logs/version_0/crop_image
# ---------------------------------
# ffmpeg version 4.4.2-0ubuntu0.22.04.1 Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 11 (Ubuntu 11.2.0-19ubuntu1)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.22.04.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libdav1d --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librabbitmq --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libsrt --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzimg --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-pocketsphinx --enable-librsvg --enable-libmfx --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared
#   libavutil      56. 70.100 / 56. 70.100
#   libavcodec     58.134.100 / 58.134.100
#   libavformat    58. 76.100 / 58. 76.100
#   libavdevice    58. 13.100 / 58. 13.100
#   libavfilter     7.110.100 /  7.110.100
#   libswscale      5.  9.100 /  5.  9.100
#   libswresample   3.  9.100 /  3.  9.100
#   libpostproc    55.  9.100 / 55.  9.100
# Input #0, image2, from '../../output/20240807/val_unsplash20k_sunrise/3.0/vae/5e-4/chk9/lightning_logs/version_0/frame/%05d.png':
#   Duration: 00:00:02.40, start: 0.000000, bitrate: N/A
#   Stream #0:0: Video: png, rgb24(pc), 512x512, 25 fps, 25 tbr, 25 tbn, 25 tbc
# Stream mapping:
#   Stream #0:0 -> #0:0 (png (native) -> h264 (libx264))
# Press [q] to stop, [?] for help
# [libx264 @ 0x564a716bf800] using cpu capabilities: MMX2 SSE2Fast SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2
# [libx264 @ 0x564a716bf800] profile High, level 2.2, 4:2:0, 8-bit
# [libx264 @ 0x564a716bf800] 264 - core 163 r3060 5db6aa6 - H.264/MPEG-4 AVC codec - Copyleft 2003-2021 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=-2 threads=16 lookahead_threads=2 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=6 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=crf mbtree=1 crf=12.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to '../../output/20240807/output_video/sunrise/01.mp4':
#   Metadata:
#     encoder         : Lavf58.76.100
#   Stream #0:0: Video: h264 (avc1 / 0x31637661), yuv420p(tv, progressive), 512x512, q=2-31, 6 fps, 12288 tbn
#     Metadata:
#       encoder         : Lavc58.134.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: N/A
# frame=   60 fps=0.0 q=-1.0 Lsize=    2382kB time=00:00:09.50 bitrate=2054.4kbits/s speed=21.9x
# video:2381kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.064149%
# [libx264 @ 0x564a716bf800] frame I:1     Avg QP: 7.87  size:182796
# [libx264 @ 0x564a716bf800] frame P:24    Avg QP: 9.08  size: 62252
# [libx264 @ 0x564a716bf800] frame B:35    Avg QP:14.92  size: 21729
# [libx264 @ 0x564a716bf800] consecutive B-frames: 15.0% 16.7% 15.0% 53.3%
# [libx264 @ 0x564a716bf800] mb I  I16..4:  3.3% 39.3% 57.4%
# [libx264 @ 0x564a716bf800] mb P  I16..4:  0.1%  0.7%  1.5%  P16..4: 68.8% 14.0% 12.4%  0.0%  0.0%    skip: 2.5%
# [libx264 @ 0x564a716bf800] mb B  I16..4:  0.0%  0.3%  0.5%  B16..8: 29.1%  5.9%  4.4%  direct:28.9%  skip:30.9%  L0:44.3% L1:47.3% BI: 8.4%
# [libx264 @ 0x564a716bf800] 8x8 transform intra:36.3% inter:41.0%
# [libx264 @ 0x564a716bf800] coded y,uvDC,uvAC intra: 99.0% 99.5% 99.0% inter: 70.1% 37.6% 21.0%
# [libx264 @ 0x564a716bf800] i16 v,h,dc,p: 49% 20% 24%  8%
# [libx264 @ 0x564a716bf800] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu: 40%  9% 15%  5%  5%  7%  6%  8%  7%
# [libx264 @ 0x564a716bf800] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 26% 10% 11%  7%  8%  9%  9% 11%  9%
# [libx264 @ 0x564a716bf800] i8c dc,h,v,p: 48%  9% 34% 10%
# [libx264 @ 0x564a716bf800] Weighted P-Frames: Y:4.2% UV:4.2%
# [libx264 @ 0x564a716bf800] ref P L0: 60.1% 12.3% 14.0% 13.5%  0.1%
# [libx264 @ 0x564a716bf800] ref B L0: 64.3% 29.4%  6.2%
# [libx264 @ 0x564a716bf800] ref B L1: 93.3%  6.7%
# [libx264 @ 0x564a716bf800] kb/s:1949.90
# ---------------------------------
# ../../output/20240807/val_unsplash20k_sunrise/5.0/vae/5e-4/chk9/lightning_logs/version_0/crop_image
# ---------------------------------
# ffmpeg version 4.4.2-0ubuntu0.22.04.1 Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 11 (Ubuntu 11.2.0-19ubuntu1)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.22.04.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libdav1d --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librabbitmq --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libsrt --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzimg --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-pocketsphinx --enable-librsvg --enable-libmfx --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared
#   libavutil      56. 70.100 / 56. 70.100
#   libavcodec     58.134.100 / 58.134.100
#   libavformat    58. 76.100 / 58. 76.100
#   libavdevice    58. 13.100 / 58. 13.100
#   libavfilter     7.110.100 /  7.110.100
#   libswscale      5.  9.100 /  5.  9.100
#   libswresample   3.  9.100 /  3.  9.100
#   libpostproc    55.  9.100 / 55.  9.100
# Input #0, image2, from '../../output/20240807/val_unsplash20k_sunrise/5.0/vae/5e-4/chk9/lightning_logs/version_0/frame/%05d.png':
#   Duration: 00:00:02.40, start: 0.000000, bitrate: N/A
#   Stream #0:0: Video: png, rgb24(pc), 512x512, 25 fps, 25 tbr, 25 tbn, 25 tbc
# Stream mapping:
#   Stream #0:0 -> #0:0 (png (native) -> h264 (libx264))
# Press [q] to stop, [?] for help
# [libx264 @ 0x55f3204b4840] using cpu capabilities: MMX2 SSE2Fast SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2
# [libx264 @ 0x55f3204b4840] profile High, level 2.2, 4:2:0, 8-bit
# [libx264 @ 0x55f3204b4840] 264 - core 163 r3060 5db6aa6 - H.264/MPEG-4 AVC codec - Copyleft 2003-2021 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=-2 threads=16 lookahead_threads=2 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=6 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=crf mbtree=1 crf=12.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to '../../output/20240807/output_video/sunrise/02.mp4':
#   Metadata:
#     encoder         : Lavf58.76.100
#   Stream #0:0: Video: h264 (avc1 / 0x31637661), yuv420p(tv, progressive), 512x512, q=2-31, 6 fps, 12288 tbn
#     Metadata:
#       encoder         : Lavc58.134.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: N/A
# frame=   60 fps=0.0 q=-1.0 Lsize=    3596kB time=00:00:09.50 bitrate=3100.8kbits/s speed=19.3x
# video:3594kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.042710%
# [libx264 @ 0x55f3204b4840] frame I:2     Avg QP:10.15  size:158304
# [libx264 @ 0x55f3204b4840] frame P:21    Avg QP:10.72  size: 85452
# [libx264 @ 0x55f3204b4840] frame B:37    Avg QP:14.91  size: 42400
# [libx264 @ 0x55f3204b4840] consecutive B-frames: 15.0%  3.3% 15.0% 66.7%
# [libx264 @ 0x55f3204b4840] mb I  I16..4:  6.1% 37.9% 56.0%
# [libx264 @ 0x55f3204b4840] mb P  I16..4:  0.6%  5.3%  9.9%  P16..4: 50.6% 18.4% 14.2%  0.0%  0.0%    skip: 1.0%
# [libx264 @ 0x55f3204b4840] mb B  I16..4:  0.1%  1.5%  3.4%  B16..8: 22.8% 10.8%  9.6%  direct:39.6%  skip:12.2%  L0:41.8% L1:38.0% BI:20.2%
# [libx264 @ 0x55f3204b4840] 8x8 transform intra:33.9% inter:43.7%
# [libx264 @ 0x55f3204b4840] coded y,uvDC,uvAC intra: 98.2% 98.4% 96.7% inter: 83.8% 51.3% 23.6%
# [libx264 @ 0x55f3204b4840] i16 v,h,dc,p: 59% 12% 14% 14%
# [libx264 @ 0x55f3204b4840] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu: 45% 10% 12%  4%  4%  6%  5%  8%  6%
# [libx264 @ 0x55f3204b4840] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 26% 11% 11%  7%  8%  9%  8% 11%  8%
# [libx264 @ 0x55f3204b4840] i8c dc,h,v,p: 43% 12% 37%  8%
# [libx264 @ 0x55f3204b4840] Weighted P-Frames: Y:19.0% UV:19.0%
# [libx264 @ 0x55f3204b4840] ref P L0: 52.3% 17.9% 17.2%  9.1%  3.5%
# [libx264 @ 0x55f3204b4840] ref B L0: 62.6% 28.7%  8.7%
# [libx264 @ 0x55f3204b4840] ref B L1: 83.6% 16.4%
# [libx264 @ 0x55f3204b4840] kb/s:2943.93
# ---------------------------------
# ../../output/20240807/val_unsplash20k_sunrise/7.0/vae/5e-4/chk9/lightning_logs/version_0/crop_image
# ---------------------------------
# ffmpeg version 4.4.2-0ubuntu0.22.04.1 Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 11 (Ubuntu 11.2.0-19ubuntu1)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.22.04.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libdav1d --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librabbitmq --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libsrt --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzimg --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-pocketsphinx --enable-librsvg --enable-libmfx --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared
#   libavutil      56. 70.100 / 56. 70.100
#   libavcodec     58.134.100 / 58.134.100
#   libavformat    58. 76.100 / 58. 76.100
#   libavdevice    58. 13.100 / 58. 13.100
#   libavfilter     7.110.100 /  7.110.100
#   libswscale      5.  9.100 /  5.  9.100
#   libswresample   3.  9.100 /  3.  9.100
#   libpostproc    55.  9.100 / 55.  9.100
# Input #0, image2, from '../../output/20240807/val_unsplash20k_sunrise/7.0/vae/5e-4/chk9/lightning_logs/version_0/frame/%05d.png':
#   Duration: 00:00:02.40, start: 0.000000, bitrate: N/A
#   Stream #0:0: Video: png, rgb24(pc), 512x512, 25 fps, 25 tbr, 25 tbn, 25 tbc
# Stream mapping:
#   Stream #0:0 -> #0:0 (png (native) -> h264 (libx264))
# Press [q] to stop, [?] for help
# [libx264 @ 0x558274d71840] using cpu capabilities: MMX2 SSE2Fast SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2
# [libx264 @ 0x558274d71840] profile High, level 2.2, 4:2:0, 8-bit
# [libx264 @ 0x558274d71840] 264 - core 163 r3060 5db6aa6 - H.264/MPEG-4 AVC codec - Copyleft 2003-2021 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=-2 threads=16 lookahead_threads=2 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=6 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=crf mbtree=1 crf=12.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to '../../output/20240807/output_video/sunrise/03.mp4':
#   Metadata:
#     encoder         : Lavf58.76.100
#   Stream #0:0: Video: h264 (avc1 / 0x31637661), yuv420p(tv, progressive), 512x512, q=2-31, 6 fps, 12288 tbn
#     Metadata:
#       encoder         : Lavc58.134.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: N/A
# frame=   60 fps=0.0 q=-1.0 Lsize=    4176kB time=00:00:09.50 bitrate=3601.4kbits/s speed=20.5x
# video:4175kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.037707%
# [libx264 @ 0x558274d71840] frame I:4     Avg QP: 8.70  size:167400
# [libx264 @ 0x558274d71840] frame P:19    Avg QP:11.51  size: 86744
# [libx264 @ 0x558274d71840] frame B:37    Avg QP:13.49  size: 52881
# [libx264 @ 0x558274d71840] consecutive B-frames: 10.0% 16.7% 20.0% 53.3%
# [libx264 @ 0x558274d71840] mb I  I16..4:  5.7% 30.0% 64.3%
# [libx264 @ 0x558274d71840] mb P  I16..4:  0.7% 10.1% 16.3%  P16..4: 42.8% 16.4% 13.5%  0.0%  0.0%    skip: 0.3%
# [libx264 @ 0x558274d71840] mb B  I16..4:  0.3%  2.8%  6.9%  B16..8: 18.0% 10.8%  9.7%  direct:34.3%  skip:17.2%  L0:57.9% L1:24.3% BI:17.8%
# [libx264 @ 0x558274d71840] 8x8 transform intra:32.4% inter:41.7%
# [libx264 @ 0x558274d71840] coded y,uvDC,uvAC intra: 98.6% 98.8% 97.3% inter: 80.5% 57.0% 22.3%
# [libx264 @ 0x558274d71840] i16 v,h,dc,p: 23% 10% 44% 23%
# [libx264 @ 0x558274d71840] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu: 28% 11% 18%  7%  6%  7%  7%  8%  8%
# [libx264 @ 0x558274d71840] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 17% 12% 12%  8% 10% 11% 10%  9% 10%
# [libx264 @ 0x558274d71840] i8c dc,h,v,p: 47% 12% 31% 10%
# [libx264 @ 0x558274d71840] Weighted P-Frames: Y:47.4% UV:36.8%
# [libx264 @ 0x558274d71840] ref P L0: 53.3% 14.7% 11.2%  6.8% 14.0%
# [libx264 @ 0x558274d71840] ref B L0: 65.5% 25.4%  9.1%
# [libx264 @ 0x558274d71840] ref B L1: 82.9% 17.1%
# [libx264 @ 0x558274d71840] kb/s:3419.47
# ---------------------------------
# ../../output/20240807/val_unsplash20k_sunrise/1.0/vae/1e-5/chk9/lightning_logs/version_0/crop_image
# ---------------------------------
# ffmpeg version 4.4.2-0ubuntu0.22.04.1 Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 11 (Ubuntu 11.2.0-19ubuntu1)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.22.04.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libdav1d --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librabbitmq --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libsrt --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzimg --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-pocketsphinx --enable-librsvg --enable-libmfx --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared
#   libavutil      56. 70.100 / 56. 70.100
#   libavcodec     58.134.100 / 58.134.100
#   libavformat    58. 76.100 / 58. 76.100
#   libavdevice    58. 13.100 / 58. 13.100
#   libavfilter     7.110.100 /  7.110.100
#   libswscale      5.  9.100 /  5.  9.100
#   libswresample   3.  9.100 /  3.  9.100
#   libpostproc    55.  9.100 / 55.  9.100
# Input #0, image2, from '../../output/20240807/val_unsplash20k_sunrise/1.0/vae/1e-5/chk9/lightning_logs/version_0/frame/%05d.png':
#   Duration: 00:00:02.40, start: 0.000000, bitrate: N/A
#   Stream #0:0: Video: png, rgb24(pc), 512x512, 25 fps, 25 tbr, 25 tbn, 25 tbc
# Stream mapping:
#   Stream #0:0 -> #0:0 (png (native) -> h264 (libx264))
# Press [q] to stop, [?] for help
# [libx264 @ 0x564be35ca800] using cpu capabilities: MMX2 SSE2Fast SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2
# [libx264 @ 0x564be35ca800] profile High, level 2.2, 4:2:0, 8-bit
# [libx264 @ 0x564be35ca800] 264 - core 163 r3060 5db6aa6 - H.264/MPEG-4 AVC codec - Copyleft 2003-2021 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=-2 threads=16 lookahead_threads=2 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=6 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=crf mbtree=1 crf=12.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to '../../output/20240807/output_video/sunrise/04.mp4':
#   Metadata:
#     encoder         : Lavf58.76.100
#   Stream #0:0: Video: h264 (avc1 / 0x31637661), yuv420p(tv, progressive), 512x512, q=2-31, 6 fps, 12288 tbn
#     Metadata:
#       encoder         : Lavc58.134.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: N/A
# frame=   60 fps=0.0 q=-1.0 Lsize=     617kB time=00:00:09.50 bitrate= 532.0kbits/s speed=34.4x
# video:615kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.244345%
# [libx264 @ 0x564be35ca800] frame I:1     Avg QP: 5.11  size:211363
# [libx264 @ 0x564be35ca800] frame P:18    Avg QP: 7.25  size: 22203
# [libx264 @ 0x564be35ca800] frame B:41    Avg QP:14.42  size:   453
# [libx264 @ 0x564be35ca800] consecutive B-frames:  5.0%  3.3% 25.0% 66.7%
# [libx264 @ 0x564be35ca800] mb I  I16..4:  0.3% 24.4% 75.3%
# [libx264 @ 0x564be35ca800] mb P  I16..4:  0.0%  0.0%  0.0%  P16..4: 73.5%  2.3%  6.8%  0.0%  0.0%    skip:17.4%
# [libx264 @ 0x564be35ca800] mb B  I16..4:  0.0%  0.0%  0.0%  B16..8: 29.7%  0.8%  0.1%  direct: 0.2%  skip:69.1%  L0:49.2% L1:47.9% BI: 2.9%
# [libx264 @ 0x564be35ca800] 8x8 transform intra:24.4% inter:40.6%
# [libx264 @ 0x564be35ca800] coded y,uvDC,uvAC intra: 99.8% 100.0% 100.0% inter: 21.3% 10.8% 10.7%
# [libx264 @ 0x564be35ca800] i16 v,h,dc,p:  0% 67% 33%  0%
# [libx264 @ 0x564be35ca800] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu: 30% 10% 11%  6%  7%  8%  7% 12% 10%
# [libx264 @ 0x564be35ca800] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 25%  9% 11%  7%  8% 11%  7% 12% 10%
# [libx264 @ 0x564be35ca800] i8c dc,h,v,p: 56% 13% 22%  9%
# [libx264 @ 0x564be35ca800] Weighted P-Frames: Y:0.0% UV:0.0%
# [libx264 @ 0x564be35ca800] ref P L0: 80.9%  0.8%  8.3% 10.0%
# [libx264 @ 0x564be35ca800] ref B L0: 64.1% 29.9%  6.0%
# [libx264 @ 0x564be35ca800] ref B L1: 92.0%  8.0%
# [libx264 @ 0x564be35ca800] kb/s:503.65
# ---------------------------------
# ../../output/20240807/val_unsplash20k_sunrise/3.0/vae/1e-5/chk9/lightning_logs/version_0/crop_image
# ---------------------------------
# ffmpeg version 4.4.2-0ubuntu0.22.04.1 Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 11 (Ubuntu 11.2.0-19ubuntu1)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.22.04.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libdav1d --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librabbitmq --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libsrt --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzimg --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-pocketsphinx --enable-librsvg --enable-libmfx --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared
#   libavutil      56. 70.100 / 56. 70.100
#   libavcodec     58.134.100 / 58.134.100
#   libavformat    58. 76.100 / 58. 76.100
#   libavdevice    58. 13.100 / 58. 13.100
#   libavfilter     7.110.100 /  7.110.100
#   libswscale      5.  9.100 /  5.  9.100
#   libswresample   3.  9.100 /  3.  9.100
#   libpostproc    55.  9.100 / 55.  9.100
# Input #0, image2, from '../../output/20240807/val_unsplash20k_sunrise/3.0/vae/1e-5/chk9/lightning_logs/version_0/frame/%05d.png':
#   Duration: 00:00:02.40, start: 0.000000, bitrate: N/A
#   Stream #0:0: Video: png, rgb24(pc), 512x512, 25 fps, 25 tbr, 25 tbn, 25 tbc
# Stream mapping:
#   Stream #0:0 -> #0:0 (png (native) -> h264 (libx264))
# Press [q] to stop, [?] for help
# [libx264 @ 0x56294f11b840] using cpu capabilities: MMX2 SSE2Fast SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2
# [libx264 @ 0x56294f11b840] profile High, level 2.2, 4:2:0, 8-bit
# [libx264 @ 0x56294f11b840] 264 - core 163 r3060 5db6aa6 - H.264/MPEG-4 AVC codec - Copyleft 2003-2021 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=-2 threads=16 lookahead_threads=2 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=6 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=crf mbtree=1 crf=12.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to '../../output/20240807/output_video/sunrise/05.mp4':
#   Metadata:
#     encoder         : Lavf58.76.100
#   Stream #0:0: Video: h264 (avc1 / 0x31637661), yuv420p(tv, progressive), 512x512, q=2-31, 6 fps, 12288 tbn
#     Metadata:
#       encoder         : Lavc58.134.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: N/A
# frame=   60 fps=0.0 q=-1.0 Lsize=    1207kB time=00:00:09.50 bitrate=1040.4kbits/s speed=31.5x
# video:1205kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.124800%
# [libx264 @ 0x56294f11b840] frame I:1     Avg QP: 5.53  size:194202
# [libx264 @ 0x56294f11b840] frame P:26    Avg QP: 6.66  size: 36006
# [libx264 @ 0x56294f11b840] frame B:33    Avg QP:14.21  size:  3119
# [libx264 @ 0x56294f11b840] consecutive B-frames: 15.0% 23.3% 35.0% 26.7%
# [libx264 @ 0x56294f11b840] mb I  I16..4:  1.2% 28.4% 70.4%
# [libx264 @ 0x56294f11b840] mb P  I16..4:  0.0%  0.0%  0.1%  P16..4: 80.6%  4.2%  8.2%  0.0%  0.0%    skip: 6.9%
# [libx264 @ 0x56294f11b840] mb B  I16..4:  0.0%  0.0%  0.0%  B16..8: 30.3%  1.5%  0.6%  direct: 1.7%  skip:65.9%  L0:41.2% L1:55.2% BI: 3.7%
# [libx264 @ 0x56294f11b840] 8x8 transform intra:27.7% inter:40.2%
# [libx264 @ 0x56294f11b840] coded y,uvDC,uvAC intra: 99.4% 99.9% 99.9% inter: 41.3% 23.2% 21.8%
# [libx264 @ 0x56294f11b840] i16 v,h,dc,p: 42% 17% 33%  8%
# [libx264 @ 0x56294f11b840] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu: 16% 12% 22%  8%  8%  6%  9% 10%  9%
# [libx264 @ 0x56294f11b840] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 15% 11% 12%  9% 11% 10% 11% 11% 11%
# [libx264 @ 0x56294f11b840] i8c dc,h,v,p: 67% 10% 14%  9%
# [libx264 @ 0x56294f11b840] Weighted P-Frames: Y:0.0% UV:0.0%
# [libx264 @ 0x56294f11b840] ref P L0: 80.7%  4.2% 10.7%  4.5%
# [libx264 @ 0x56294f11b840] ref B L0: 70.1% 27.6%  2.3%
# [libx264 @ 0x56294f11b840] ref B L1: 94.7%  5.3%
# [libx264 @ 0x56294f11b840] kb/s:986.63
# ---------------------------------
# ../../output/20240807/val_unsplash20k_sunrise/5.0/vae/1e-5/chk9/lightning_logs/version_0/crop_image
# ---------------------------------
# ffmpeg version 4.4.2-0ubuntu0.22.04.1 Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 11 (Ubuntu 11.2.0-19ubuntu1)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.22.04.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libdav1d --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librabbitmq --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libsrt --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzimg --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-pocketsphinx --enable-librsvg --enable-libmfx --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared
#   libavutil      56. 70.100 / 56. 70.100
#   libavcodec     58.134.100 / 58.134.100
#   libavformat    58. 76.100 / 58. 76.100
#   libavdevice    58. 13.100 / 58. 13.100
#   libavfilter     7.110.100 /  7.110.100
#   libswscale      5.  9.100 /  5.  9.100
#   libswresample   3.  9.100 /  3.  9.100
#   libpostproc    55.  9.100 / 55.  9.100
# Input #0, image2, from '../../output/20240807/val_unsplash20k_sunrise/5.0/vae/1e-5/chk9/lightning_logs/version_0/frame/%05d.png':
#   Duration: 00:00:02.40, start: 0.000000, bitrate: N/A
#   Stream #0:0: Video: png, rgb24(pc), 512x512, 25 fps, 25 tbr, 25 tbn, 25 tbc
# Stream mapping:
#   Stream #0:0 -> #0:0 (png (native) -> h264 (libx264))
# Press [q] to stop, [?] for help
# [libx264 @ 0x55a9a9191840] using cpu capabilities: MMX2 SSE2Fast SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2
# [libx264 @ 0x55a9a9191840] profile High, level 2.2, 4:2:0, 8-bit
# [libx264 @ 0x55a9a9191840] 264 - core 163 r3060 5db6aa6 - H.264/MPEG-4 AVC codec - Copyleft 2003-2021 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=-2 threads=16 lookahead_threads=2 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=6 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=crf mbtree=1 crf=12.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to '../../output/20240807/output_video/sunrise/06.mp4':
#   Metadata:
#     encoder         : Lavf58.76.100
#   Stream #0:0: Video: h264 (avc1 / 0x31637661), yuv420p(tv, progressive), 512x512, q=2-31, 6 fps, 12288 tbn
#     Metadata:
#       encoder         : Lavc58.134.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: N/A
# frame=   60 fps=0.0 q=-1.0 Lsize=    1306kB time=00:00:09.50 bitrate=1126.2kbits/s speed=28.1x
# video:1304kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.117686%
# [libx264 @ 0x55a9a9191840] frame I:1     Avg QP: 5.75  size:185298
# [libx264 @ 0x55a9a9191840] frame P:21    Avg QP: 7.02  size: 43908
# [libx264 @ 0x55a9a9191840] frame B:38    Avg QP:14.33  size:  5992
# [libx264 @ 0x55a9a9191840] consecutive B-frames:  6.7% 23.3% 10.0% 60.0%
# [libx264 @ 0x55a9a9191840] mb I  I16..4:  1.7% 31.4% 66.9%
# [libx264 @ 0x55a9a9191840] mb P  I16..4:  0.0%  0.1%  0.1%  P16..4: 74.8%  8.5% 12.8%  0.0%  0.0%    skip: 3.6%
# [libx264 @ 0x55a9a9191840] mb B  I16..4:  0.0%  0.0%  0.0%  B16..8: 34.7%  3.5%  2.2%  direct: 5.4%  skip:54.1%  L0:46.6% L1:46.5% BI: 6.9%
# [libx264 @ 0x55a9a9191840] 8x8 transform intra:31.2% inter:40.3%
# [libx264 @ 0x55a9a9191840] coded y,uvDC,uvAC intra: 99.3% 99.8% 99.5% inter: 43.4% 20.3% 18.3%
# [libx264 @ 0x55a9a9191840] i16 v,h,dc,p: 21% 17% 58%  4%
# [libx264 @ 0x55a9a9191840] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu: 14% 13% 19%  8%  8%  8%  8% 10% 11%
# [libx264 @ 0x55a9a9191840] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 15% 13% 10%  8% 10% 10% 11% 10% 12%
# [libx264 @ 0x55a9a9191840] i8c dc,h,v,p: 72%  9% 12%  7%
# [libx264 @ 0x55a9a9191840] Weighted P-Frames: Y:0.0% UV:0.0%
# [libx264 @ 0x55a9a9191840] ref P L0: 76.3%  6.1% 12.7%  4.9%
# [libx264 @ 0x55a9a9191840] ref B L0: 69.0% 28.6%  2.3%
# [libx264 @ 0x55a9a9191840] ref B L1: 90.8%  9.2%
# [libx264 @ 0x55a9a9191840] kb/s:1068.05
# ---------------------------------
# ../../output/20240807/val_unsplash20k_sunrise/7.0/vae/1e-5/chk9/lightning_logs/version_0/crop_image
# ---------------------------------
# ffmpeg version 4.4.2-0ubuntu0.22.04.1 Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 11 (Ubuntu 11.2.0-19ubuntu1)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.22.04.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libdav1d --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librabbitmq --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libsrt --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzimg --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-pocketsphinx --enable-librsvg --enable-libmfx --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared
#   libavutil      56. 70.100 / 56. 70.100
#   libavcodec     58.134.100 / 58.134.100
#   libavformat    58. 76.100 / 58. 76.100
#   libavdevice    58. 13.100 / 58. 13.100
#   libavfilter     7.110.100 /  7.110.100
#   libswscale      5.  9.100 /  5.  9.100
#   libswresample   3.  9.100 /  3.  9.100
#   libpostproc    55.  9.100 / 55.  9.100
# Input #0, image2, from '../../output/20240807/val_unsplash20k_sunrise/7.0/vae/1e-5/chk9/lightning_logs/version_0/frame/%05d.png':
#   Duration: 00:00:02.40, start: 0.000000, bitrate: N/A
#   Stream #0:0: Video: png, rgb24(pc), 512x512, 25 fps, 25 tbr, 25 tbn, 25 tbc
# Stream mapping:
#   Stream #0:0 -> #0:0 (png (native) -> h264 (libx264))
# Press [q] to stop, [?] for help
# [libx264 @ 0x560298d34840] using cpu capabilities: MMX2 SSE2Fast SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2
# [libx264 @ 0x560298d34840] profile High, level 2.2, 4:2:0, 8-bit
# [libx264 @ 0x560298d34840] 264 - core 163 r3060 5db6aa6 - H.264/MPEG-4 AVC codec - Copyleft 2003-2021 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=-2 threads=16 lookahead_threads=2 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=6 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=crf mbtree=1 crf=12.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to '../../output/20240807/output_video/sunrise/07.mp4':
#   Metadata:
#     encoder         : Lavf58.76.100
#   Stream #0:0: Video: h264 (avc1 / 0x31637661), yuv420p(tv, progressive), 512x512, q=2-31, 6 fps, 12288 tbn
#     Metadata:
#       encoder         : Lavc58.134.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: N/A
# frame=   60 fps=0.0 q=-1.0 Lsize=    1973kB time=00:00:09.50 bitrate=1701.4kbits/s speed=24.6x
# video:1972kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.075488%
# [libx264 @ 0x560298d34840] frame I:1     Avg QP: 7.29  size:164618
# [libx264 @ 0x560298d34840] frame P:22    Avg QP: 8.22  size: 56645
# [libx264 @ 0x560298d34840] frame B:37    Avg QP:14.07  size: 16415
# [libx264 @ 0x560298d34840] consecutive B-frames:  8.3% 16.7% 35.0% 40.0%
# [libx264 @ 0x560298d34840] mb I  I16..4:  1.5% 37.6% 60.9%
# [libx264 @ 0x560298d34840] mb P  I16..4:  0.2%  1.0%  1.9%  P16..4: 64.5% 15.1% 16.7%  0.0%  0.0%    skip: 0.7%
# [libx264 @ 0x560298d34840] mb B  I16..4:  0.0%  0.1%  0.4%  B16..8: 30.8%  7.7%  6.3%  direct:18.5%  skip:36.2%  L0:45.4% L1:41.1% BI:13.6%
# [libx264 @ 0x560298d34840] 8x8 transform intra:33.4% inter:42.1%
# [libx264 @ 0x560298d34840] coded y,uvDC,uvAC intra: 97.9% 98.8% 97.7% inter: 61.4% 30.0% 20.3%
# [libx264 @ 0x560298d34840] i16 v,h,dc,p: 43% 15% 28% 13%
# [libx264 @ 0x560298d34840] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu: 14% 12% 18%  7% 10% 10% 10%  8% 10%
# [libx264 @ 0x560298d34840] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 13% 14% 12%  8% 11% 11% 12%  8% 11%
# [libx264 @ 0x560298d34840] i8c dc,h,v,p: 64% 16% 14%  7%
# [libx264 @ 0x560298d34840] Weighted P-Frames: Y:13.6% UV:4.5%
# [libx264 @ 0x560298d34840] ref P L0: 63.0% 14.6% 14.2%  5.5%  2.6%
# [libx264 @ 0x560298d34840] ref B L0: 63.8% 29.2%  7.0%
# [libx264 @ 0x560298d34840] ref B L1: 97.3%  2.7%
# [libx264 @ 0x560298d34840] kb/s:1614.54
