# %%
import os

# %%
CONTROLS = ['both','depth']
GUIDANCES = ['1.0','3.0','5.0','7.0']

# %%
for control in CONTROLS:
   for guidance in GUIDANCES:
        root_dir = f'../../output/20240902/val_face_roll60_v2/{guidance}/{control}/1e-4/chk319/lightning_logs/version_0'
        input_dir = root_dir + '/crop_image'
        output_dir = root_dir + f'/video_crop'
        os.makedirs(output_dir, exist_ok=True)
        # create directory
        for face_id in range(10):
            if os.path.exists(f'{output_dir}/{face_id:04d}.mp4'):
                continue
            cmd = f'ffmpeg -r 6 -i "{input_dir}/{face_id:05d}_02%03d.jpg" -c:v libx264 -crf 12 -pix_fmt yuv420p {output_dir}/{face_id:04d}.mp4'
            #print(cmd)
            os.system(cmd)
# Out:
# ffmpeg version 4.4.2-0ubuntu0.22.04.1 Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 11 (Ubuntu 11.2.0-19ubuntu1)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.22.04.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libdav1d --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librabbitmq --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libsrt --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzimg --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-pocketsphinx --enable-librsvg --enable-libmfx --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared
#   libavutil      56. 70.100 / 56. 70.100
#   libavcodec     58.134.100 / 58.134.100
#   libavformat    58. 76.100 / 58. 76.100
#   libavdevice    58. 13.100 / 58. 13.100
#   libavfilter     7.110.100 /  7.110.100
#   libswscale      5.  9.100 /  5.  9.100
#   libswresample   3.  9.100 /  3.  9.100
#   libpostproc    55.  9.100 / 55.  9.100
# Input #0, image2, from '../../output/20240902/val_face_roll60_v2/1.0/both/1e-4/chk319/lightning_logs/version_0/crop_image/00001_02%03d.jpg':
#   Duration: 00:00:02.40, start: 0.000000, bitrate: N/A
#   Stream #0:0: Video: mjpeg (Baseline), yuvj420p(pc, bt470bg/unknown/unknown), 512x512 [SAR 1:1 DAR 1:1], 25 fps, 25 tbr, 25 tbn, 25 tbc
# Stream mapping:
#   Stream #0:0 -> #0:0 (mjpeg (native) -> h264 (libx264))
# Press [q] to stop, [?] for help
# [swscaler @ 0x557511aa75c0] deprecated pixel format used, make sure you did set range correctly
# [libx264 @ 0x557511881380] using SAR=1/1
# [libx264 @ 0x557511881380] using cpu capabilities: MMX2 SSE2Fast SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2
# [libx264 @ 0x557511881380] profile High, level 2.2, 4:2:0, 8-bit
# [libx264 @ 0x557511881380] 264 - core 163 r3060 5db6aa6 - H.264/MPEG-4 AVC codec - Copyleft 2003-2021 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=-2 threads=16 lookahead_threads=2 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=6 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=crf mbtree=1 crf=12.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to '../../output/20240902/val_face_roll60_v2/1.0/both/1e-4/chk319/lightning_logs/version_0/video_crop/0001.mp4':
#   Metadata:
#     encoder         : Lavf58.76.100
#   Stream #0:0: Video: h264 (avc1 / 0x31637661), yuv420p(tv, bt470bg/unknown/unknown, progressive), 512x512 [SAR 1:1 DAR 1:1], q=2-31, 6 fps, 12288 tbn
#     Metadata:
#       encoder         : Lavc58.134.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: N/A
# frame=   60 fps=0.0 q=-1.0 Lsize=    1934kB time=00:00:09.50 bitrate=1667.7kbits/s speed=24.2x
# video:1932kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.080656%
# [libx264 @ 0x557511881380] frame I:1     Avg QP: 9.52  size: 58995
# [libx264 @ 0x557511881380] frame P:15    Avg QP: 9.52  size: 49614
# [libx264 @ 0x557511881380] frame B:44    Avg QP:12.01  size: 26702
# [libx264 @ 0x557511881380] consecutive B-frames:  1.7%  0.0%  5.0% 93.3%
# [libx264 @ 0x557511881380] mb I  I16..4:  2.9% 91.7%  5.4%
# [libx264 @ 0x557511881380] mb P  I16..4:  1.0% 31.7%  5.3%  P16..4: 28.1% 21.7% 11.6%  0.0%  0.0%    skip: 0.5%
# [libx264 @ 0x557511881380] mb B  I16..4:  0.3%  4.2%  1.0%  B16..8: 26.3% 14.6% 10.8%  direct:41.6%  skip: 1.3%  L0:41.7% L1:31.0% BI:27.3%
# [libx264 @ 0x557511881380] 8x8 transform intra:82.7% inter:93.3%
# [libx264 @ 0x557511881380] coded y,uvDC,uvAC intra: 92.6% 93.8% 85.4% inter: 91.6% 93.0% 61.5%
# [libx264 @ 0x557511881380] i16 v,h,dc,p: 40% 21% 28% 11%
# [libx264 @ 0x557511881380] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu: 25% 15% 16%  3%  7% 14%  5%  8%  6%
# [libx264 @ 0x557511881380] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 22% 15% 11%  6% 10% 16%  7%  8%  6%
# [libx264 @ 0x557511881380] i8c dc,h,v,p: 43% 19% 27% 11%
# [libx264 @ 0x557511881380] Weighted P-Frames: Y:53.3% UV:53.3%
# [libx264 @ 0x557511881380] ref P L0: 31.0% 20.3% 18.3% 21.8%  8.6%
# [libx264 @ 0x557511881380] ref B L0: 70.5% 24.5%  5.0%
# [libx264 @ 0x557511881380] ref B L1: 86.1% 13.9%
# [libx264 @ 0x557511881380] kb/s:1582.47
# ffmpeg version 4.4.2-0ubuntu0.22.04.1 Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 11 (Ubuntu 11.2.0-19ubuntu1)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.22.04.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libdav1d --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librabbitmq --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libsrt --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzimg --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-pocketsphinx --enable-librsvg --enable-libmfx --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared
#   libavutil      56. 70.100 / 56. 70.100
#   libavcodec     58.134.100 / 58.134.100
#   libavformat    58. 76.100 / 58. 76.100
#   libavdevice    58. 13.100 / 58. 13.100
#   libavfilter     7.110.100 /  7.110.100
#   libswscale      5.  9.100 /  5.  9.100
#   libswresample   3.  9.100 /  3.  9.100
#   libpostproc    55.  9.100 / 55.  9.100
# Input #0, image2, from '../../output/20240902/val_face_roll60_v2/1.0/both/1e-4/chk319/lightning_logs/version_0/crop_image/00002_02%03d.jpg':
#   Duration: 00:00:02.40, start: 0.000000, bitrate: N/A
#   Stream #0:0: Video: mjpeg (Baseline), yuvj420p(pc, bt470bg/unknown/unknown), 512x512 [SAR 1:1 DAR 1:1], 25 fps, 25 tbr, 25 tbn, 25 tbc
# Stream mapping:
#   Stream #0:0 -> #0:0 (mjpeg (native) -> h264 (libx264))
# Press [q] to stop, [?] for help
# [swscaler @ 0x555e17aedc00] deprecated pixel format used, make sure you did set range correctly
# [libx264 @ 0x555e17951840] using SAR=1/1
# [libx264 @ 0x555e17951840] using cpu capabilities: MMX2 SSE2Fast SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2
# [libx264 @ 0x555e17951840] profile High, level 2.2, 4:2:0, 8-bit
# [libx264 @ 0x555e17951840] 264 - core 163 r3060 5db6aa6 - H.264/MPEG-4 AVC codec - Copyleft 2003-2021 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=-2 threads=16 lookahead_threads=2 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=6 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=crf mbtree=1 crf=12.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to '../../output/20240902/val_face_roll60_v2/1.0/both/1e-4/chk319/lightning_logs/version_0/video_crop/0002.mp4':
#   Metadata:
#     encoder         : Lavf58.76.100
#   Stream #0:0: Video: h264 (avc1 / 0x31637661), yuv420p(tv, bt470bg/unknown/unknown, progressive), 512x512 [SAR 1:1 DAR 1:1], q=2-31, 6 fps, 12288 tbn
#     Metadata:
#       encoder         : Lavc58.134.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: N/A
# frame=   60 fps=0.0 q=-1.0 Lsize=    1590kB time=00:00:09.50 bitrate=1371.1kbits/s speed=30.8x
# video:1588kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.098858%
# [libx264 @ 0x555e17951840] frame I:1     Avg QP: 8.81  size: 43044
# [libx264 @ 0x555e17951840] frame P:15    Avg QP: 8.99  size: 39339
# [libx264 @ 0x555e17951840] frame B:44    Avg QP:10.92  size: 22563
# [libx264 @ 0x555e17951840] consecutive B-frames:  1.7%  0.0%  5.0% 93.3%
# [libx264 @ 0x555e17951840] mb I  I16..4:  2.3% 88.0%  9.7%
# [libx264 @ 0x555e17951840] mb P  I16..4:  0.7% 47.2%  9.8%  P16..4: 19.1% 15.3%  7.9%  0.0%  0.0%    skip: 0.0%
# [libx264 @ 0x555e17951840] mb B  I16..4:  0.2% 10.0%  3.1%  B16..8: 22.2% 12.7%  9.9%  direct:41.8%  skip: 0.0%  L0:41.6% L1:30.4% BI:27.9%
# [libx264 @ 0x555e17951840] 8x8 transform intra:79.8% inter:89.1%
# [libx264 @ 0x555e17951840] coded y,uvDC,uvAC intra: 97.0% 67.8% 41.7% inter: 95.2% 87.8% 28.4%
# [libx264 @ 0x555e17951840] i16 v,h,dc,p: 11% 13% 26% 50%
# [libx264 @ 0x555e17951840] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu: 24% 22% 21%  3%  5%  6%  6%  6%  6%
# [libx264 @ 0x555e17951840] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 23% 21% 14%  6%  9%  7%  8%  6%  5%
# [libx264 @ 0x555e17951840] i8c dc,h,v,p: 41% 27% 26%  6%
# [libx264 @ 0x555e17951840] Weighted P-Frames: Y:53.3% UV:46.7%
# [libx264 @ 0x555e17951840] ref P L0: 33.6% 21.3% 17.3% 16.0% 11.9%
# [libx264 @ 0x555e17951840] ref B L0: 67.3% 26.4%  6.3%
# [libx264 @ 0x555e17951840] ref B L1: 85.8% 14.2%
# [libx264 @ 0x555e17951840] kb/s:1300.71
# ffmpeg version 4.4.2-0ubuntu0.22.04.1 Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 11 (Ubuntu 11.2.0-19ubuntu1)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.22.04.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libdav1d --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librabbitmq --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libsrt --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzimg --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-pocketsphinx --enable-librsvg --enable-libmfx --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared
#   libavutil      56. 70.100 / 56. 70.100
#   libavcodec     58.134.100 / 58.134.100
#   libavformat    58. 76.100 / 58. 76.100
#   libavdevice    58. 13.100 / 58. 13.100
#   libavfilter     7.110.100 /  7.110.100
#   libswscale      5.  9.100 /  5.  9.100
#   libswresample   3.  9.100 /  3.  9.100
#   libpostproc    55.  9.100 / 55.  9.100
# Input #0, image2, from '../../output/20240902/val_face_roll60_v2/1.0/both/1e-4/chk319/lightning_logs/version_0/crop_image/00003_02%03d.jpg':
#   Duration: 00:00:02.40, start: 0.000000, bitrate: N/A
#   Stream #0:0: Video: mjpeg (Baseline), yuvj420p(pc, bt470bg/unknown/unknown), 512x512 [SAR 1:1 DAR 1:1], 25 fps, 25 tbr, 25 tbn, 25 tbc
# Stream mapping:
#   Stream #0:0 -> #0:0 (mjpeg (native) -> h264 (libx264))
# Press [q] to stop, [?] for help
# [swscaler @ 0x556eae705100] deprecated pixel format used, make sure you did set range correctly
# [libx264 @ 0x556eae533c00] using SAR=1/1
# [libx264 @ 0x556eae533c00] using cpu capabilities: MMX2 SSE2Fast SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2
# [libx264 @ 0x556eae533c00] profile High, level 2.2, 4:2:0, 8-bit
# [libx264 @ 0x556eae533c00] 264 - core 163 r3060 5db6aa6 - H.264/MPEG-4 AVC codec - Copyleft 2003-2021 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=-2 threads=16 lookahead_threads=2 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=6 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=crf mbtree=1 crf=12.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to '../../output/20240902/val_face_roll60_v2/1.0/both/1e-4/chk319/lightning_logs/version_0/video_crop/0003.mp4':
#   Metadata:
#     encoder         : Lavf58.76.100
#   Stream #0:0: Video: h264 (avc1 / 0x31637661), yuv420p(tv, bt470bg/unknown/unknown, progressive), 512x512 [SAR 1:1 DAR 1:1], q=2-31, 6 fps, 12288 tbn
#     Metadata:
#       encoder         : Lavc58.134.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: N/A
# frame=   60 fps=0.0 q=-1.0 Lsize=    1545kB time=00:00:09.50 bitrate=1332.5kbits/s speed=33.1x
# video:1544kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.101721%
# [libx264 @ 0x556eae533c00] frame I:1     Avg QP: 8.01  size: 50428
# [libx264 @ 0x556eae533c00] frame P:15    Avg QP: 8.10  size: 41519
# [libx264 @ 0x556eae533c00] frame B:44    Avg QP:10.62  size: 20611
# [libx264 @ 0x556eae533c00] consecutive B-frames:  1.7%  0.0%  5.0% 93.3%
# [libx264 @ 0x556eae533c00] mb I  I16..4:  3.0% 91.5%  5.5%
# [libx264 @ 0x556eae533c00] mb P  I16..4:  2.3% 37.7%  6.3%  P16..4: 24.6% 18.0% 11.1%  0.0%  0.0%    skip: 0.0%
# [libx264 @ 0x556eae533c00] mb B  I16..4:  0.5%  8.9%  1.1%  B16..8: 24.6% 13.9% 12.8%  direct:37.9%  skip: 0.2%  L0:43.5% L1:32.5% BI:24.0%
# [libx264 @ 0x556eae533c00] 8x8 transform intra:83.3% inter:90.5%
# [libx264 @ 0x556eae533c00] coded y,uvDC,uvAC intra: 85.4% 60.5% 38.3% inter: 90.2% 86.5% 30.7%
# [libx264 @ 0x556eae533c00] i16 v,h,dc,p: 24% 20% 32% 23%
# [libx264 @ 0x556eae533c00] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu: 22% 22% 30%  3%  3%  4%  4%  5%  6%
# [libx264 @ 0x556eae533c00] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 27% 22% 15%  6%  7%  6%  6%  5%  6%
# [libx264 @ 0x556eae533c00] i8c dc,h,v,p: 49% 23% 22%  6%
# [libx264 @ 0x556eae533c00] Weighted P-Frames: Y:53.3% UV:53.3%
# [libx264 @ 0x556eae533c00] ref P L0: 34.6% 21.2% 18.3% 18.7%  7.2%
# [libx264 @ 0x556eae533c00] ref B L0: 68.4% 25.3%  6.3%
# [libx264 @ 0x556eae533c00] ref B L1: 87.2% 12.8%
# [libx264 @ 0x556eae533c00] kb/s:1264.08
# ffmpeg version 4.4.2-0ubuntu0.22.04.1 Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 11 (Ubuntu 11.2.0-19ubuntu1)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.22.04.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libdav1d --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librabbitmq --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libsrt --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzimg --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-pocketsphinx --enable-librsvg --enable-libmfx --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared
#   libavutil      56. 70.100 / 56. 70.100
#   libavcodec     58.134.100 / 58.134.100
#   libavformat    58. 76.100 / 58. 76.100
#   libavdevice    58. 13.100 / 58. 13.100
#   libavfilter     7.110.100 /  7.110.100
#   libswscale      5.  9.100 /  5.  9.100
#   libswresample   3.  9.100 /  3.  9.100
#   libpostproc    55.  9.100 / 55.  9.100
# Input #0, image2, from '../../output/20240902/val_face_roll60_v2/1.0/both/1e-4/chk319/lightning_logs/version_0/crop_image/00004_02%03d.jpg':
#   Duration: 00:00:02.40, start: 0.000000, bitrate: N/A
#   Stream #0:0: Video: mjpeg (Baseline), yuvj420p(pc, bt470bg/unknown/unknown), 512x512 [SAR 1:1 DAR 1:1], 25 fps, 25 tbr, 25 tbn, 25 tbc
# Stream mapping:
#   Stream #0:0 -> #0:0 (mjpeg (native) -> h264 (libx264))
# Press [q] to stop, [?] for help
# [swscaler @ 0x55cd137716c0] deprecated pixel format used, make sure you did set range correctly
# [libx264 @ 0x55cd13510140] using SAR=1/1
# [libx264 @ 0x55cd13510140] using cpu capabilities: MMX2 SSE2Fast SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2
# [libx264 @ 0x55cd13510140] profile High, level 2.2, 4:2:0, 8-bit
# [libx264 @ 0x55cd13510140] 264 - core 163 r3060 5db6aa6 - H.264/MPEG-4 AVC codec - Copyleft 2003-2021 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=-2 threads=16 lookahead_threads=2 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=6 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=crf mbtree=1 crf=12.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to '../../output/20240902/val_face_roll60_v2/1.0/both/1e-4/chk319/lightning_logs/version_0/video_crop/0004.mp4':
#   Metadata:
#     encoder         : Lavf58.76.100
#   Stream #0:0: Video: h264 (avc1 / 0x31637661), yuv420p(tv, bt470bg/unknown/unknown, progressive), 512x512 [SAR 1:1 DAR 1:1], q=2-31, 6 fps, 12288 tbn
#     Metadata:
#       encoder         : Lavc58.134.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: N/A
# frame=   60 fps=0.0 q=-1.0 Lsize=    2207kB time=00:00:09.50 bitrate=1903.3kbits/s speed=28.4x
# video:2206kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.071903%
# [libx264 @ 0x55cd13510140] frame I:1     Avg QP: 9.35  size: 66574
# [libx264 @ 0x55cd13510140] frame P:15    Avg QP: 9.48  size: 56204
# [libx264 @ 0x55cd13510140] frame B:44    Avg QP:12.18  size: 30643
# [libx264 @ 0x55cd13510140] consecutive B-frames:  1.7%  0.0%  5.0% 93.3%
# [libx264 @ 0x55cd13510140] mb I  I16..4:  1.1% 93.0%  6.0%
# [libx264 @ 0x55cd13510140] mb P  I16..4:  0.2% 31.3%  4.5%  P16..4: 29.2% 23.6% 11.2%  0.0%  0.0%    skip: 0.0%
# [libx264 @ 0x55cd13510140] mb B  I16..4:  0.0%  3.7%  0.7%  B16..8: 28.0% 15.1% 11.1%  direct:41.5%  skip: 0.0%  L0:38.3% L1:29.9% BI:31.8%
# [libx264 @ 0x55cd13510140] 8x8 transform intra:87.0% inter:94.5%
# [libx264 @ 0x55cd13510140] coded y,uvDC,uvAC intra: 98.9% 91.3% 73.4% inter: 97.8% 96.6% 62.6%
# [libx264 @ 0x55cd13510140] i16 v,h,dc,p:  7%  2% 28% 63%
# [libx264 @ 0x55cd13510140] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu: 25% 13% 28%  4%  4%  6%  4%  9%  6%
# [libx264 @ 0x55cd13510140] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 25% 14% 13%  7%  8% 10%  7%  9%  7%
# [libx264 @ 0x55cd13510140] i8c dc,h,v,p: 45% 19% 29%  7%
# [libx264 @ 0x55cd13510140] Weighted P-Frames: Y:60.0% UV:60.0%
# [libx264 @ 0x55cd13510140] ref P L0: 31.7% 24.3% 18.8% 16.9%  8.4%
# [libx264 @ 0x55cd13510140] ref B L0: 71.0% 23.5%  5.5%
# [libx264 @ 0x55cd13510140] ref B L1: 85.9% 14.1%
# [libx264 @ 0x55cd13510140] kb/s:1806.33
# ffmpeg version 4.4.2-0ubuntu0.22.04.1 Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 11 (Ubuntu 11.2.0-19ubuntu1)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.22.04.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libdav1d --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librabbitmq --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libsrt --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzimg --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-pocketsphinx --enable-librsvg --enable-libmfx --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared
#   libavutil      56. 70.100 / 56. 70.100
#   libavcodec     58.134.100 / 58.134.100
#   libavformat    58. 76.100 / 58. 76.100
#   libavdevice    58. 13.100 / 58. 13.100
#   libavfilter     7.110.100 /  7.110.100
#   libswscale      5.  9.100 /  5.  9.100
#   libswresample   3.  9.100 /  3.  9.100
#   libpostproc    55.  9.100 / 55.  9.100
# Input #0, image2, from '../../output/20240902/val_face_roll60_v2/1.0/both/1e-4/chk319/lightning_logs/version_0/crop_image/00005_02%03d.jpg':
#   Duration: 00:00:02.40, start: 0.000000, bitrate: N/A
#   Stream #0:0: Video: mjpeg (Baseline), yuvj420p(pc, bt470bg/unknown/unknown), 512x512 [SAR 1:1 DAR 1:1], 25 fps, 25 tbr, 25 tbn, 25 tbc
# Stream mapping:
#   Stream #0:0 -> #0:0 (mjpeg (native) -> h264 (libx264))
# Press [q] to stop, [?] for help
# [swscaler @ 0x560077682240] deprecated pixel format used, make sure you did set range correctly
# [libx264 @ 0x5600774de180] using SAR=1/1
# [libx264 @ 0x5600774de180] using cpu capabilities: MMX2 SSE2Fast SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2
# [libx264 @ 0x5600774de180] profile High, level 2.2, 4:2:0, 8-bit
# [libx264 @ 0x5600774de180] 264 - core 163 r3060 5db6aa6 - H.264/MPEG-4 AVC codec - Copyleft 2003-2021 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=-2 threads=16 lookahead_threads=2 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=6 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=crf mbtree=1 crf=12.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to '../../output/20240902/val_face_roll60_v2/1.0/both/1e-4/chk319/lightning_logs/version_0/video_crop/0005.mp4':
#   Metadata:
#     encoder         : Lavf58.76.100
#   Stream #0:0: Video: h264 (avc1 / 0x31637661), yuv420p(tv, bt470bg/unknown/unknown, progressive), 512x512 [SAR 1:1 DAR 1:1], q=2-31, 6 fps, 12288 tbn
#     Metadata:
#       encoder         : Lavc58.134.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: N/A
# frame=   60 fps=0.0 q=-1.0 Lsize=    1571kB time=00:00:09.50 bitrate=1354.4kbits/s speed=32.5x
# video:1569kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.100076%
# [libx264 @ 0x5600774de180] frame I:1     Avg QP: 7.78  size: 45112
# [libx264 @ 0x5600774de180] frame P:15    Avg QP: 8.59  size: 37704
# [libx264 @ 0x5600774de180] frame B:44    Avg QP:10.45  size: 22623
# [libx264 @ 0x5600774de180] consecutive B-frames:  1.7%  0.0%  5.0% 93.3%
# [libx264 @ 0x5600774de180] mb I  I16..4:  2.5% 87.2% 10.3%
# [libx264 @ 0x5600774de180] mb P  I16..4:  1.9% 44.9%  7.3%  P16..4: 20.3% 16.2%  9.4%  0.0%  0.0%    skip: 0.0%
# [libx264 @ 0x5600774de180] mb B  I16..4:  0.9% 19.7%  3.1%  B16..8: 20.2% 12.8% 10.6%  direct:32.6%  skip: 0.1%  L0:42.7% L1:31.9% BI:25.5%
# [libx264 @ 0x5600774de180] 8x8 transform intra:83.2% inter:93.1%
# [libx264 @ 0x5600774de180] coded y,uvDC,uvAC intra: 82.9% 49.7% 31.1% inter: 91.0% 85.0% 38.5%
# [libx264 @ 0x5600774de180] i16 v,h,dc,p: 55% 16% 20%  9%
# [libx264 @ 0x5600774de180] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu: 47% 20% 20%  2%  2%  3%  2%  2%  3%
# [libx264 @ 0x5600774de180] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 45% 20% 11%  4%  5%  5%  4%  3%  3%
# [libx264 @ 0x5600774de180] i8c dc,h,v,p: 46% 14% 36%  3%
# [libx264 @ 0x5600774de180] Weighted P-Frames: Y:66.7% UV:46.7%
# [libx264 @ 0x5600774de180] ref P L0: 35.4% 19.5% 17.6% 17.9%  9.6%
# [libx264 @ 0x5600774de180] ref B L0: 69.6% 25.2%  5.2%
# [libx264 @ 0x5600774de180] ref B L1: 85.3% 14.7%
# [libx264 @ 0x5600774de180] kb/s:1284.87
# ffmpeg version 4.4.2-0ubuntu0.22.04.1 Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 11 (Ubuntu 11.2.0-19ubuntu1)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.22.04.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libdav1d --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librabbitmq --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libsrt --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzimg --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-pocketsphinx --enable-librsvg --enable-libmfx --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared
#   libavutil      56. 70.100 / 56. 70.100
#   libavcodec     58.134.100 / 58.134.100
#   libavformat    58. 76.100 / 58. 76.100
#   libavdevice    58. 13.100 / 58. 13.100
#   libavfilter     7.110.100 /  7.110.100
#   libswscale      5.  9.100 /  5.  9.100
#   libswresample   3.  9.100 /  3.  9.100
#   libpostproc    55.  9.100 / 55.  9.100
# Input #0, image2, from '../../output/20240902/val_face_roll60_v2/1.0/both/1e-4/chk319/lightning_logs/version_0/crop_image/00006_02%03d.jpg':
#   Duration: 00:00:02.40, start: 0.000000, bitrate: N/A
#   Stream #0:0: Video: mjpeg (Baseline), yuvj420p(pc, bt470bg/unknown/unknown), 512x512 [SAR 1:1 DAR 1:1], 25 fps, 25 tbr, 25 tbn, 25 tbc
# Stream mapping:
#   Stream #0:0 -> #0:0 (mjpeg (native) -> h264 (libx264))
# Press [q] to stop, [?] for help
# [swscaler @ 0x557f95473a00] deprecated pixel format used, make sure you did set range correctly
# [libx264 @ 0x557f95279f40] using SAR=1/1
# [libx264 @ 0x557f95279f40] using cpu capabilities: MMX2 SSE2Fast SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2
# [libx264 @ 0x557f95279f40] profile High, level 2.2, 4:2:0, 8-bit
# [libx264 @ 0x557f95279f40] 264 - core 163 r3060 5db6aa6 - H.264/MPEG-4 AVC codec - Copyleft 2003-2021 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=-2 threads=16 lookahead_threads=2 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=6 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=crf mbtree=1 crf=12.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to '../../output/20240902/val_face_roll60_v2/1.0/both/1e-4/chk319/lightning_logs/version_0/video_crop/0006.mp4':
#   Metadata:
#     encoder         : Lavf58.76.100
#   Stream #0:0: Video: h264 (avc1 / 0x31637661), yuv420p(tv, bt470bg/unknown/unknown, progressive), 512x512 [SAR 1:1 DAR 1:1], q=2-31, 6 fps, 12288 tbn
#     Metadata:
#       encoder         : Lavc58.134.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: N/A
# frame=   60 fps=0.0 q=-1.0 Lsize=    1939kB time=00:00:09.50 bitrate=1672.3kbits/s speed=29.9x
# video:1938kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.080432%
# [libx264 @ 0x557f95279f40] frame I:1     Avg QP: 8.73  size: 58747
# [libx264 @ 0x557f95279f40] frame P:15    Avg QP: 9.05  size: 49867
# [libx264 @ 0x557f95279f40] frame B:44    Avg QP:11.69  size: 26746
# [libx264 @ 0x557f95279f40] consecutive B-frames:  1.7%  0.0%  5.0% 93.3%
# [libx264 @ 0x557f95279f40] mb I  I16..4:  1.3% 93.3%  5.5%
# [libx264 @ 0x557f95279f40] mb P  I16..4:  0.2% 29.8%  5.7%  P16..4: 28.3% 23.4% 12.5%  0.0%  0.0%    skip: 0.0%
# [libx264 @ 0x557f95279f40] mb B  I16..4:  0.0%  3.7%  0.9%  B16..8: 28.3% 15.2% 10.0%  direct:41.7%  skip: 0.1%  L0:39.8% L1:30.7% BI:29.6%
# [libx264 @ 0x557f95279f40] 8x8 transform intra:83.6% inter:89.9%
# [libx264 @ 0x557f95279f40] coded y,uvDC,uvAC intra: 98.2% 89.5% 69.6% inter: 94.1% 93.3% 54.0%
# [libx264 @ 0x557f95279f40] i16 v,h,dc,p:  9%  8% 40% 43%
# [libx264 @ 0x557f95279f40] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu: 22% 20% 22%  4%  5%  5%  5%  9%  7%
# [libx264 @ 0x557f95279f40] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 22% 19% 13%  7%  8%  7%  7%  9%  8%
# [libx264 @ 0x557f95279f40] i8c dc,h,v,p: 45% 23% 22%  9%
# [libx264 @ 0x557f95279f40] Weighted P-Frames: Y:66.7% UV:66.7%
# [libx264 @ 0x557f95279f40] ref P L0: 34.5% 20.6% 16.2% 15.9% 12.8%
# [libx264 @ 0x557f95279f40] ref B L0: 68.4% 25.4%  6.3%
# [libx264 @ 0x557f95279f40] ref B L1: 84.9% 15.1%
# [libx264 @ 0x557f95279f40] kb/s:1586.87
# ffmpeg version 4.4.2-0ubuntu0.22.04.1 Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 11 (Ubuntu 11.2.0-19ubuntu1)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.22.04.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libdav1d --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librabbitmq --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libsrt --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzimg --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-pocketsphinx --enable-librsvg --enable-libmfx --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared
#   libavutil      56. 70.100 / 56. 70.100
#   libavcodec     58.134.100 / 58.134.100
#   libavformat    58. 76.100 / 58. 76.100
#   libavdevice    58. 13.100 / 58. 13.100
#   libavfilter     7.110.100 /  7.110.100
#   libswscale      5.  9.100 /  5.  9.100
#   libswresample   3.  9.100 /  3.  9.100
#   libpostproc    55.  9.100 / 55.  9.100
# Input #0, image2, from '../../output/20240902/val_face_roll60_v2/1.0/both/1e-4/chk319/lightning_logs/version_0/crop_image/00007_02%03d.jpg':
#   Duration: 00:00:02.40, start: 0.000000, bitrate: N/A
#   Stream #0:0: Video: mjpeg (Baseline), yuvj420p(pc, bt470bg/unknown/unknown), 512x512 [SAR 1:1 DAR 1:1], 25 fps, 25 tbr, 25 tbn, 25 tbc
# Stream mapping:
#   Stream #0:0 -> #0:0 (mjpeg (native) -> h264 (libx264))
# Press [q] to stop, [?] for help
# [swscaler @ 0x55fbc487c000] deprecated pixel format used, make sure you did set range correctly
# [libx264 @ 0x55fbc46a0bc0] using SAR=1/1
# [libx264 @ 0x55fbc46a0bc0] using cpu capabilities: MMX2 SSE2Fast SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2
# [libx264 @ 0x55fbc46a0bc0] profile High, level 2.2, 4:2:0, 8-bit
# [libx264 @ 0x55fbc46a0bc0] 264 - core 163 r3060 5db6aa6 - H.264/MPEG-4 AVC codec - Copyleft 2003-2021 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=-2 threads=16 lookahead_threads=2 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=6 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=crf mbtree=1 crf=12.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to '../../output/20240902/val_face_roll60_v2/1.0/both/1e-4/chk319/lightning_logs/version_0/video_crop/0007.mp4':
#   Metadata:
#     encoder         : Lavf58.76.100
#   Stream #0:0: Video: h264 (avc1 / 0x31637661), yuv420p(tv, bt470bg/unknown/unknown, progressive), 512x512 [SAR 1:1 DAR 1:1], q=2-31, 6 fps, 12288 tbn
#     Metadata:
#       encoder         : Lavc58.134.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: N/A
# frame=   60 fps=0.0 q=-1.0 Lsize=    1859kB time=00:00:09.50 bitrate=1603.0kbits/s speed=32.9x
# video:1857kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.084545%
# [libx264 @ 0x55fbc46a0bc0] frame I:1     Avg QP: 8.75  size: 55086
# [libx264 @ 0x55fbc46a0bc0] frame P:15    Avg QP: 8.92  size: 46862
# [libx264 @ 0x55fbc46a0bc0] frame B:44    Avg QP:11.14  size: 25983
# [libx264 @ 0x55fbc46a0bc0] consecutive B-frames:  1.7%  0.0%  5.0% 93.3%
# [libx264 @ 0x55fbc46a0bc0] mb I  I16..4:  1.9% 91.6%  6.5%
# [libx264 @ 0x55fbc46a0bc0] mb P  I16..4:  1.0% 39.7%  6.1%  P16..4: 23.9% 18.9% 10.3%  0.0%  0.0%    skip: 0.1%
# [libx264 @ 0x55fbc46a0bc0] mb B  I16..4:  0.3%  7.1%  1.4%  B16..8: 25.4% 14.1% 10.3%  direct:41.1%  skip: 0.3%  L0:43.0% L1:30.6% BI:26.3%
# [libx264 @ 0x55fbc46a0bc0] 8x8 transform intra:84.1% inter:91.7%
# [libx264 @ 0x55fbc46a0bc0] coded y,uvDC,uvAC intra: 92.5% 82.5% 64.0% inter: 90.8% 90.0% 47.2%
# [libx264 @ 0x55fbc46a0bc0] i16 v,h,dc,p: 29% 13% 28% 30%
# [libx264 @ 0x55fbc46a0bc0] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu: 25% 17% 24%  4%  5%  7%  6%  6%  7%
# [libx264 @ 0x55fbc46a0bc0] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 22% 17% 13%  7% 10% 10%  8%  6%  6%
# [libx264 @ 0x55fbc46a0bc0] i8c dc,h,v,p: 42% 21% 27%  9%
# [libx264 @ 0x55fbc46a0bc0] Weighted P-Frames: Y:53.3% UV:46.7%
# [libx264 @ 0x55fbc46a0bc0] ref P L0: 31.7% 20.7% 17.6% 18.2% 11.8%
# [libx264 @ 0x55fbc46a0bc0] ref B L0: 67.6% 26.1%  6.3%
# [libx264 @ 0x55fbc46a0bc0] ref B L1: 86.1% 13.9%
# [libx264 @ 0x55fbc46a0bc0] kb/s:1521.00
# ffmpeg version 4.4.2-0ubuntu0.22.04.1 Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 11 (Ubuntu 11.2.0-19ubuntu1)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.22.04.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libdav1d --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librabbitmq --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libsrt --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzimg --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-pocketsphinx --enable-librsvg --enable-libmfx --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared
#   libavutil      56. 70.100 / 56. 70.100
#   libavcodec     58.134.100 / 58.134.100
#   libavformat    58. 76.100 / 58. 76.100
#   libavdevice    58. 13.100 / 58. 13.100
#   libavfilter     7.110.100 /  7.110.100
#   libswscale      5.  9.100 /  5.  9.100
#   libswresample   3.  9.100 /  3.  9.100
#   libpostproc    55.  9.100 / 55.  9.100
# Input #0, image2, from '../../output/20240902/val_face_roll60_v2/1.0/both/1e-4/chk319/lightning_logs/version_0/crop_image/00008_02%03d.jpg':
#   Duration: 00:00:02.40, start: 0.000000, bitrate: N/A
#   Stream #0:0: Video: mjpeg (Baseline), yuvj420p(pc, bt470bg/unknown/unknown), 512x512 [SAR 1:1 DAR 1:1], 25 fps, 25 tbr, 25 tbn, 25 tbc
# Stream mapping:
#   Stream #0:0 -> #0:0 (mjpeg (native) -> h264 (libx264))
# Press [q] to stop, [?] for help
# [swscaler @ 0x5621fa674a00] deprecated pixel format used, make sure you did set range correctly
# [libx264 @ 0x5621fa484480] using SAR=1/1
# [libx264 @ 0x5621fa484480] using cpu capabilities: MMX2 SSE2Fast SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2
# [libx264 @ 0x5621fa484480] profile High, level 2.2, 4:2:0, 8-bit
# [libx264 @ 0x5621fa484480] 264 - core 163 r3060 5db6aa6 - H.264/MPEG-4 AVC codec - Copyleft 2003-2021 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=-2 threads=16 lookahead_threads=2 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=6 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=crf mbtree=1 crf=12.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to '../../output/20240902/val_face_roll60_v2/1.0/both/1e-4/chk319/lightning_logs/version_0/video_crop/0008.mp4':
#   Metadata:
#     encoder         : Lavf58.76.100
#   Stream #0:0: Video: h264 (avc1 / 0x31637661), yuv420p(tv, bt470bg/unknown/unknown, progressive), 512x512 [SAR 1:1 DAR 1:1], q=2-31, 6 fps, 12288 tbn
#     Metadata:
#       encoder         : Lavc58.134.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: N/A
# frame=   60 fps=0.0 q=-1.0 Lsize=    1899kB time=00:00:09.50 bitrate=1637.4kbits/s speed=32.4x
# video:1897kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.082146%
# [libx264 @ 0x5621fa484480] frame I:1     Avg QP: 9.01  size: 53031
# [libx264 @ 0x5621fa484480] frame P:15    Avg QP: 9.01  size: 47505
# [libx264 @ 0x5621fa484480] frame B:44    Avg QP:11.06  size: 26741
# [libx264 @ 0x5621fa484480] consecutive B-frames:  1.7%  0.0%  5.0% 93.3%
# [libx264 @ 0x5621fa484480] mb I  I16..4:  1.7% 92.0%  6.3%
# [libx264 @ 0x5621fa484480] mb P  I16..4:  0.7% 42.5%  7.0%  P16..4: 22.6% 17.5%  9.6%  0.0%  0.0%    skip: 0.0%
# [libx264 @ 0x5621fa484480] mb B  I16..4:  0.2%  8.9%  1.7%  B16..8: 24.3% 13.2% 10.9%  direct:40.9%  skip: 0.0%  L0:42.1% L1:32.0% BI:25.9%
# [libx264 @ 0x5621fa484480] 8x8 transform intra:84.5% inter:92.2%
# [libx264 @ 0x5621fa484480] coded y,uvDC,uvAC intra: 94.8% 87.2% 70.3% inter: 94.7% 93.1% 50.2%
# [libx264 @ 0x5621fa484480] i16 v,h,dc,p: 29%  9% 40% 23%
# [libx264 @ 0x5621fa484480] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu: 25% 19% 22%  3%  6%  8%  6%  7%  5%
# [libx264 @ 0x5621fa484480] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 27% 16% 14%  5%  9% 11%  6%  8%  4%
# [libx264 @ 0x5621fa484480] i8c dc,h,v,p: 40% 24% 29%  7%
# [libx264 @ 0x5621fa484480] Weighted P-Frames: Y:46.7% UV:40.0%
# [libx264 @ 0x5621fa484480] ref P L0: 33.2% 23.3% 15.7% 20.7%  7.1%
# [libx264 @ 0x5621fa484480] ref B L0: 67.0% 26.5%  6.5%
# [libx264 @ 0x5621fa484480] ref B L1: 85.9% 14.1%
# [libx264 @ 0x5621fa484480] kb/s:1553.75
# ffmpeg version 4.4.2-0ubuntu0.22.04.1 Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 11 (Ubuntu 11.2.0-19ubuntu1)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.22.04.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libdav1d --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librabbitmq --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libsrt --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzimg --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-pocketsphinx --enable-librsvg --enable-libmfx --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared
#   libavutil      56. 70.100 / 56. 70.100
#   libavcodec     58.134.100 / 58.134.100
#   libavformat    58. 76.100 / 58. 76.100
#   libavdevice    58. 13.100 / 58. 13.100
#   libavfilter     7.110.100 /  7.110.100
#   libswscale      5.  9.100 /  5.  9.100
#   libswresample   3.  9.100 /  3.  9.100
#   libpostproc    55.  9.100 / 55.  9.100
# Input #0, image2, from '../../output/20240902/val_face_roll60_v2/1.0/both/1e-4/chk319/lightning_logs/version_0/crop_image/00009_02%03d.jpg':
#   Duration: 00:00:02.40, start: 0.000000, bitrate: N/A
#   Stream #0:0: Video: mjpeg (Baseline), yuvj420p(pc, bt470bg/unknown/unknown), 512x512 [SAR 1:1 DAR 1:1], 25 fps, 25 tbr, 25 tbn, 25 tbc
# Stream mapping:
#   Stream #0:0 -> #0:0 (mjpeg (native) -> h264 (libx264))
# Press [q] to stop, [?] for help
# [swscaler @ 0x55774d2db240] deprecated pixel format used, make sure you did set range correctly
# [libx264 @ 0x55774d10cb00] using SAR=1/1
# [libx264 @ 0x55774d10cb00] using cpu capabilities: MMX2 SSE2Fast SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2
# [libx264 @ 0x55774d10cb00] profile High, level 2.2, 4:2:0, 8-bit
# [libx264 @ 0x55774d10cb00] 264 - core 163 r3060 5db6aa6 - H.264/MPEG-4 AVC codec - Copyleft 2003-2021 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=-2 threads=16 lookahead_threads=2 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=6 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=crf mbtree=1 crf=12.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to '../../output/20240902/val_face_roll60_v2/1.0/both/1e-4/chk319/lightning_logs/version_0/video_crop/0009.mp4':
#   Metadata:
#     encoder         : Lavf58.76.100
#   Stream #0:0: Video: h264 (avc1 / 0x31637661), yuv420p(tv, bt470bg/unknown/unknown, progressive), 512x512 [SAR 1:1 DAR 1:1], q=2-31, 6 fps, 12288 tbn
#     Metadata:
#       encoder         : Lavc58.134.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: N/A
# frame=   60 fps=0.0 q=-1.0 Lsize=    1653kB time=00:00:09.50 bitrate=1425.7kbits/s speed=35.7x
# video:1652kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.095071%
# [libx264 @ 0x55774d10cb00] frame I:1     Avg QP: 8.69  size: 45577
# [libx264 @ 0x55774d10cb00] frame P:15    Avg QP: 9.00  size: 40125
# [libx264 @ 0x55774d10cb00] frame B:44    Avg QP:11.13  size: 23710
# [libx264 @ 0x55774d10cb00] consecutive B-frames:  1.7%  0.0%  5.0% 93.3%
# [libx264 @ 0x55774d10cb00] mb I  I16..4:  3.8% 89.6%  6.5%
# [libx264 @ 0x55774d10cb00] mb P  I16..4:  5.3% 39.6%  6.4%  P16..4: 21.4% 17.4%  8.9%  0.0%  0.0%    skip: 1.1%
# [libx264 @ 0x55774d10cb00] mb B  I16..4:  0.9%  9.2%  2.2%  B16..8: 23.1% 14.9%  9.7%  direct:36.7%  skip: 3.3%  L0:41.3% L1:30.8% BI:27.9%
# [libx264 @ 0x55774d10cb00] 8x8 transform intra:77.3% inter:92.3%
# [libx264 @ 0x55774d10cb00] coded y,uvDC,uvAC intra: 88.0% 74.0% 50.1% inter: 88.0% 87.7% 35.1%
# [libx264 @ 0x55774d10cb00] i16 v,h,dc,p: 42% 29%  4% 25%
# [libx264 @ 0x55774d10cb00] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu: 19% 38% 15%  3%  4%  5%  5%  6%  6%
# [libx264 @ 0x55774d10cb00] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 19% 30% 11%  6%  8%  6%  7%  6%  6%
# [libx264 @ 0x55774d10cb00] i8c dc,h,v,p: 36% 35% 22%  7%
# [libx264 @ 0x55774d10cb00] Weighted P-Frames: Y:40.0% UV:26.7%
# [libx264 @ 0x55774d10cb00] ref P L0: 30.9% 23.8% 19.7% 18.4%  7.2%
# [libx264 @ 0x55774d10cb00] ref B L0: 67.7% 25.4%  7.0%
# [libx264 @ 0x55774d10cb00] ref B L1: 85.4% 14.6%
# [libx264 @ 0x55774d10cb00] kb/s:1352.55
# ffmpeg version 4.4.2-0ubuntu0.22.04.1 Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 11 (Ubuntu 11.2.0-19ubuntu1)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.22.04.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libdav1d --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librabbitmq --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libsrt --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzimg --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-pocketsphinx --enable-librsvg --enable-libmfx --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared
#   libavutil      56. 70.100 / 56. 70.100
#   libavcodec     58.134.100 / 58.134.100
#   libavformat    58. 76.100 / 58. 76.100
#   libavdevice    58. 13.100 / 58. 13.100
#   libavfilter     7.110.100 /  7.110.100
#   libswscale      5.  9.100 /  5.  9.100
#   libswresample   3.  9.100 /  3.  9.100
#   libpostproc    55.  9.100 / 55.  9.100
# ...
# [libx264 @ 0x564792dd98c0] i16 v,h,dc,p: 28% 37% 16% 19%
# [libx264 @ 0x564792dd98c0] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu: 18% 29% 12%  4%  7%  8%  7%  8%  6%
# [libx264 @ 0x564792dd98c0] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 18% 22% 10%  7% 10%  9%  8%  9%  7%
# [libx264 @ 0x564792dd98c0] i8c dc,h,v,p: 43% 26% 19% 12%
# [libx264 @ 0x564792dd98c0] Weighted P-Frames: Y:44.0% UV:44.0%
# [libx264 @ 0x564792dd98c0] ref P L0: 37.0% 18.5% 20.8% 18.6%  5.1%
# [libx264 @ 0x564792dd98c0] ref B L0: 67.9% 29.1%  2.9%
# [libx264 @ 0x564792dd98c0] ref B L1: 86.2% 13.8%
# [libx264 @ 0x564792dd98c0] kb/s:2443.20
# ffmpeg version 4.4.2-0ubuntu0.22.04.1 Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 11 (Ubuntu 11.2.0-19ubuntu1)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.22.04.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libdav1d --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librabbitmq --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libsrt --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzimg --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-pocketsphinx --enable-librsvg --enable-libmfx --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared
#   libavutil      56. 70.100 / 56. 70.100
#   libavcodec     58.134.100 / 58.134.100
#   libavformat    58. 76.100 / 58. 76.100
#   libavdevice    58. 13.100 / 58. 13.100
#   libavfilter     7.110.100 /  7.110.100
#   libswscale      5.  9.100 /  5.  9.100
#   libswresample   3.  9.100 /  3.  9.100
#   libpostproc    55.  9.100 / 55.  9.100
# Input #0, image2, from '../../output/20240902/val_face_roll60_v2/7.0/depth/1e-4/chk319/lightning_logs/version_0/crop_image/00007_02%03d.jpg':
#   Duration: 00:00:02.40, start: 0.000000, bitrate: N/A
#   Stream #0:0: Video: mjpeg (Baseline), yuvj420p(pc, bt470bg/unknown/unknown), 512x512 [SAR 1:1 DAR 1:1], 25 fps, 25 tbr, 25 tbn, 25 tbc
# Stream mapping:
#   Stream #0:0 -> #0:0 (mjpeg (native) -> h264 (libx264))
# Press [q] to stop, [?] for help
# [swscaler @ 0x55a480997180] deprecated pixel format used, make sure you did set range correctly
# [libx264 @ 0x55a48077e8c0] using SAR=1/1
# [libx264 @ 0x55a48077e8c0] using cpu capabilities: MMX2 SSE2Fast SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2
# [libx264 @ 0x55a48077e8c0] profile High, level 2.2, 4:2:0, 8-bit
# [libx264 @ 0x55a48077e8c0] 264 - core 163 r3060 5db6aa6 - H.264/MPEG-4 AVC codec - Copyleft 2003-2021 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=-2 threads=16 lookahead_threads=2 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=6 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=crf mbtree=1 crf=12.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to '../../output/20240902/val_face_roll60_v2/7.0/depth/1e-4/chk319/lightning_logs/version_0/video_crop/0007.mp4':
#   Metadata:
#     encoder         : Lavf58.76.100
#   Stream #0:0: Video: h264 (avc1 / 0x31637661), yuv420p(tv, bt470bg/unknown/unknown, progressive), 512x512 [SAR 1:1 DAR 1:1], q=2-31, 6 fps, 12288 tbn
#     Metadata:
#       encoder         : Lavc58.134.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: N/A
# frame=   60 fps=0.0 q=-1.0 Lsize=    2880kB time=00:00:09.50 bitrate=2483.8kbits/s speed=29.8x
# video:2879kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.054140%
# [libx264 @ 0x55a48077e8c0] frame I:7     Avg QP: 9.16  size: 56687
# [libx264 @ 0x55a48077e8c0] frame P:23    Avg QP:11.95  size: 48048
# [libx264 @ 0x55a48077e8c0] frame B:30    Avg QP:12.15  size: 48177
# [libx264 @ 0x55a48077e8c0] consecutive B-frames: 21.7% 30.0% 15.0% 33.3%
# [libx264 @ 0x55a48077e8c0] mb I  I16..4:  4.0% 86.8%  9.2%
# [libx264 @ 0x55a48077e8c0] mb P  I16..4:  2.6% 83.7%  7.5%  P16..4:  2.1%  2.0%  1.7%  0.0%  0.0%    skip: 0.2%
# [libx264 @ 0x55a48077e8c0] mb B  I16..4:  2.2% 47.0% 19.7%  B16..8:  4.4%  6.6%  4.6%  direct:15.1%  skip: 0.5%  L0:43.4% L1:27.2% BI:29.4%
# [libx264 @ 0x55a48077e8c0] 8x8 transform intra:80.0% inter:94.4%
# [libx264 @ 0x55a48077e8c0] coded y,uvDC,uvAC intra: 94.4% 90.5% 79.1% inter: 91.7% 95.0% 82.2%
# [libx264 @ 0x55a48077e8c0] i16 v,h,dc,p: 44% 14% 16% 26%
# [libx264 @ 0x55a48077e8c0] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu: 24% 13% 13%  6%  7% 11%  6% 12%  7%
# [libx264 @ 0x55a48077e8c0] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 21% 13% 10%  8% 10% 12%  8% 11%  7%
# [libx264 @ 0x55a48077e8c0] i8c dc,h,v,p: 43% 17% 27% 12%
# [libx264 @ 0x55a48077e8c0] Weighted P-Frames: Y:43.5% UV:43.5%
# [libx264 @ 0x55a48077e8c0] ref P L0: 36.0% 14.2% 27.8% 17.1%  4.9%
# [libx264 @ 0x55a48077e8c0] ref B L0: 69.2% 27.8%  3.0%
# [libx264 @ 0x55a48077e8c0] ref B L1: 91.5%  8.5%
# [libx264 @ 0x55a48077e8c0] kb/s:2357.79
# ffmpeg version 4.4.2-0ubuntu0.22.04.1 Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 11 (Ubuntu 11.2.0-19ubuntu1)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.22.04.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libdav1d --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librabbitmq --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libsrt --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzimg --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-pocketsphinx --enable-librsvg --enable-libmfx --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared
#   libavutil      56. 70.100 / 56. 70.100
#   libavcodec     58.134.100 / 58.134.100
#   libavformat    58. 76.100 / 58. 76.100
#   libavdevice    58. 13.100 / 58. 13.100
#   libavfilter     7.110.100 /  7.110.100
#   libswscale      5.  9.100 /  5.  9.100
#   libswresample   3.  9.100 /  3.  9.100
#   libpostproc    55.  9.100 / 55.  9.100
# Input #0, image2, from '../../output/20240902/val_face_roll60_v2/7.0/depth/1e-4/chk319/lightning_logs/version_0/crop_image/00008_02%03d.jpg':
#   Duration: 00:00:02.40, start: 0.000000, bitrate: N/A
#   Stream #0:0: Video: mjpeg (Baseline), yuvj420p(pc, bt470bg/unknown/unknown), 512x512 [SAR 1:1 DAR 1:1], 25 fps, 25 tbr, 25 tbn, 25 tbc
# Stream mapping:
#   Stream #0:0 -> #0:0 (mjpeg (native) -> h264 (libx264))
# Press [q] to stop, [?] for help
# [swscaler @ 0x5562ff961800] deprecated pixel format used, make sure you did set range correctly
# [libx264 @ 0x5562ff776280] using SAR=1/1
# [libx264 @ 0x5562ff776280] using cpu capabilities: MMX2 SSE2Fast SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2
# [libx264 @ 0x5562ff776280] profile High, level 2.2, 4:2:0, 8-bit
# [libx264 @ 0x5562ff776280] 264 - core 163 r3060 5db6aa6 - H.264/MPEG-4 AVC codec - Copyleft 2003-2021 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=-2 threads=16 lookahead_threads=2 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=6 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=crf mbtree=1 crf=12.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to '../../output/20240902/val_face_roll60_v2/7.0/depth/1e-4/chk319/lightning_logs/version_0/video_crop/0008.mp4':
#   Metadata:
#     encoder         : Lavf58.76.100
#   Stream #0:0: Video: h264 (avc1 / 0x31637661), yuv420p(tv, bt470bg/unknown/unknown, progressive), 512x512 [SAR 1:1 DAR 1:1], q=2-31, 6 fps, 12288 tbn
#     Metadata:
#       encoder         : Lavc58.134.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: N/A
# frame=   60 fps=0.0 q=-1.0 Lsize=    2505kB time=00:00:09.50 bitrate=2160.1kbits/s speed=  32x
# video:2504kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.057418%
# [libx264 @ 0x5562ff776280] frame I:5     Avg QP: 8.79  size: 51445
# [libx264 @ 0x5562ff776280] frame P:31    Avg QP:11.20  size: 41069
# [libx264 @ 0x5562ff776280] frame B:24    Avg QP:11.57  size: 43025
# [libx264 @ 0x5562ff776280] consecutive B-frames: 43.3%  6.7% 10.0% 40.0%
# [libx264 @ 0x5562ff776280] mb I  I16..4:  5.1% 86.5%  8.4%
# [libx264 @ 0x5562ff776280] mb P  I16..4:  2.4% 82.0%  8.1%  P16..4:  3.0%  2.7%  1.7%  0.0%  0.0%    skip: 0.1%
# [libx264 @ 0x5562ff776280] mb B  I16..4:  1.8% 47.2% 17.9%  B16..8:  5.7%  7.2%  5.6%  direct:14.0%  skip: 0.6%  L0:42.8% L1:31.6% BI:25.5%
# [libx264 @ 0x5562ff776280] 8x8 transform intra:82.6% inter:95.5%
# [libx264 @ 0x5562ff776280] coded y,uvDC,uvAC intra: 93.9% 77.5% 62.9% inter: 92.6% 87.5% 59.7%
# [libx264 @ 0x5562ff776280] i16 v,h,dc,p: 29% 25% 27% 19%
# [libx264 @ 0x5562ff776280] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu: 24% 15% 15%  4%  8% 10%  6% 12%  6%
# [libx264 @ 0x5562ff776280] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 22% 15% 11%  7% 11% 12%  8% 10%  6%
# [libx264 @ 0x5562ff776280] i8c dc,h,v,p: 45% 20% 27%  8%
# [libx264 @ 0x5562ff776280] Weighted P-Frames: Y:32.3% UV:22.6%
# [libx264 @ 0x5562ff776280] ref P L0: 32.6% 16.6% 23.3% 22.8%  4.7%
# [libx264 @ 0x5562ff776280] ref B L0: 68.1% 26.1%  5.9%
# [libx264 @ 0x5562ff776280] ref B L1: 86.9% 13.1%
# [libx264 @ 0x5562ff776280] kb/s:2050.37
# ffmpeg version 4.4.2-0ubuntu0.22.04.1 Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 11 (Ubuntu 11.2.0-19ubuntu1)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.22.04.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libdav1d --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librabbitmq --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libsrt --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzimg --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-pocketsphinx --enable-librsvg --enable-libmfx --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared
#   libavutil      56. 70.100 / 56. 70.100
#   libavcodec     58.134.100 / 58.134.100
#   libavformat    58. 76.100 / 58. 76.100
#   libavdevice    58. 13.100 / 58. 13.100
#   libavfilter     7.110.100 /  7.110.100
#   libswscale      5.  9.100 /  5.  9.100
#   libswresample   3.  9.100 /  3.  9.100
#   libpostproc    55.  9.100 / 55.  9.100
# Input #0, image2, from '../../output/20240902/val_face_roll60_v2/7.0/depth/1e-4/chk319/lightning_logs/version_0/crop_image/00009_02%03d.jpg':
#   Duration: 00:00:02.40, start: 0.000000, bitrate: N/A
#   Stream #0:0: Video: mjpeg (Baseline), yuvj420p(pc, bt470bg/unknown/unknown), 512x512 [SAR 1:1 DAR 1:1], 25 fps, 25 tbr, 25 tbn, 25 tbc
# Stream mapping:
#   Stream #0:0 -> #0:0 (mjpeg (native) -> h264 (libx264))
# Press [q] to stop, [?] for help
# [swscaler @ 0x55d8773028c0] deprecated pixel format used, make sure you did set range correctly
# [libx264 @ 0x55d8772d1d80] using SAR=1/1
# [libx264 @ 0x55d8772d1d80] using cpu capabilities: MMX2 SSE2Fast SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2
# [libx264 @ 0x55d8772d1d80] profile High, level 2.2, 4:2:0, 8-bit
# [libx264 @ 0x55d8772d1d80] 264 - core 163 r3060 5db6aa6 - H.264/MPEG-4 AVC codec - Copyleft 2003-2021 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=-2 threads=16 lookahead_threads=2 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=6 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=crf mbtree=1 crf=12.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to '../../output/20240902/val_face_roll60_v2/7.0/depth/1e-4/chk319/lightning_logs/version_0/video_crop/0009.mp4':
#   Metadata:
#     encoder         : Lavf58.76.100
#   Stream #0:0: Video: h264 (avc1 / 0x31637661), yuv420p(tv, bt470bg/unknown/unknown, progressive), 512x512 [SAR 1:1 DAR 1:1], q=2-31, 6 fps, 12288 tbn
#     Metadata:
#       encoder         : Lavc58.134.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: N/A
# frame=   60 fps=0.0 q=-1.0 Lsize=    2525kB time=00:00:09.50 bitrate=2177.7kbits/s speed=32.6x
# video:2524kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.062218%
# [libx264 @ 0x55d8772d1d80] frame I:7     Avg QP: 8.45  size: 51336
# [libx264 @ 0x55d8772d1d80] frame P:20    Avg QP:10.95  size: 41166
# [libx264 @ 0x55d8772d1d80] frame B:33    Avg QP:11.12  size: 42458
# [libx264 @ 0x55d8772d1d80] consecutive B-frames: 21.7% 13.3%  5.0% 60.0%
# [libx264 @ 0x55d8772d1d80] mb I  I16..4: 10.1% 82.0%  7.9%
# [libx264 @ 0x55d8772d1d80] mb P  I16..4:  9.1% 78.2%  6.5%  P16..4:  2.0%  1.9%  1.3%  0.0%  0.0%    skip: 1.0%
# [libx264 @ 0x55d8772d1d80] mb B  I16..4:  8.8% 46.0% 16.9%  B16..8:  4.4%  6.2%  4.1%  direct:12.5%  skip: 1.2%  L0:40.9% L1:30.7% BI:28.4%
# [libx264 @ 0x55d8772d1d80] 8x8 transform intra:74.0% inter:96.8%
# [libx264 @ 0x55d8772d1d80] coded y,uvDC,uvAC intra: 83.6% 78.1% 65.4% inter: 84.6% 91.0% 70.9%
# [libx264 @ 0x55d8772d1d80] i16 v,h,dc,p: 52% 35%  8%  5%
# [libx264 @ 0x55d8772d1d80] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu: 21% 25% 14%  4%  6%  7%  8%  7%  8%
# [libx264 @ 0x55d8772d1d80] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 18% 21% 10%  7%  9%  9%  9%  8%  9%
# [libx264 @ 0x55d8772d1d80] i8c dc,h,v,p: 44% 26% 21%  9%
# [libx264 @ 0x55d8772d1d80] Weighted P-Frames: Y:20.0% UV:20.0%
# [libx264 @ 0x55d8772d1d80] ref P L0: 40.8% 16.3% 21.7% 19.7%  1.4%
# [libx264 @ 0x55d8772d1d80] ref B L0: 73.7% 24.2%  2.1%
# [libx264 @ 0x55d8772d1d80] ref B L1: 85.5% 14.5%
# [libx264 @ 0x55d8772d1d80] kb/s:2067.02

# %%
for control in CONTROLS:
   for guidance in GUIDANCES:
        root_dir = f'../../output/20240902/val_face_roll60_v2/{guidance}/{control}/1e-4/chk319/lightning_logs/version_0'
        input_dir = root_dir + '/video_frame'
        output_file = root_dir + f'/video_grid.mp4'
        if os.path.exists(f'{output_file}.mp4'):
            continue
        cmd = f'ffmpeg -r 6 -i "{input_dir}/%03d.jpg" -c:v libx264 -crf 12 -pix_fmt yuv420p {output_file}.mp4'
        os.system(cmd)
# Out:
# ffmpeg version 4.4.2-0ubuntu0.22.04.1 Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 11 (Ubuntu 11.2.0-19ubuntu1)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.22.04.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libdav1d --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librabbitmq --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libsrt --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzimg --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-pocketsphinx --enable-librsvg --enable-libmfx --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared
#   libavutil      56. 70.100 / 56. 70.100
#   libavcodec     58.134.100 / 58.134.100
#   libavformat    58. 76.100 / 58. 76.100
#   libavdevice    58. 13.100 / 58. 13.100
#   libavfilter     7.110.100 /  7.110.100
#   libswscale      5.  9.100 /  5.  9.100
#   libswresample   3.  9.100 /  3.  9.100
#   libpostproc    55.  9.100 / 55.  9.100
# Input #0, image2, from '../../output/20240902/val_face_roll60_v2/1.0/both/1e-4/chk319/lightning_logs/version_0/video_frame/%03d.jpg':
#   Duration: 00:00:02.40, start: 0.000000, bitrate: N/A
#   Stream #0:0: Video: mjpeg (Baseline), yuvj420p(pc, bt470bg/unknown/unknown), 1034x776 [SAR 1:1 DAR 517:388], 25 fps, 25 tbr, 25 tbn, 25 tbc
# Stream mapping:
#   Stream #0:0 -> #0:0 (mjpeg (native) -> h264 (libx264))
# Press [q] to stop, [?] for help
# [swscaler @ 0x55e683743b80] deprecated pixel format used, make sure you did set range correctly
# [libx264 @ 0x55e683229380] using SAR=1/1
# [libx264 @ 0x55e683229380] using cpu capabilities: MMX2 SSE2Fast SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2
# [libx264 @ 0x55e683229380] profile High, level 3.1, 4:2:0, 8-bit
# [libx264 @ 0x55e683229380] 264 - core 163 r3060 5db6aa6 - H.264/MPEG-4 AVC codec - Copyleft 2003-2021 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=-2 threads=24 lookahead_threads=4 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=6 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=crf mbtree=1 crf=12.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to '../../output/20240902/val_face_roll60_v2/1.0/both/1e-4/chk319/lightning_logs/version_0/video_grid.mp4.mp4':
#   Metadata:
#     encoder         : Lavf58.76.100
#   Stream #0:0: Video: h264 (avc1 / 0x31637661), yuv420p(tv, bt470bg/unknown/unknown, progressive), 1034x776 [SAR 1:1 DAR 517:388], q=2-31, 6 fps, 12288 tbn
#     Metadata:
#       encoder         : Lavc58.134.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: N/A
# frame=   60 fps= 11 q=-1.0 Lsize=    5810kB time=00:00:09.50 bitrate=5010.0kbits/s speed=1.71x
# video:5808kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.027742%
# [libx264 @ 0x55e683229380] frame I:1     Avg QP: 8.45  size:200846
# [libx264 @ 0x55e683229380] frame P:15    Avg QP: 9.89  size:149703
# [libx264 @ 0x55e683229380] frame B:44    Avg QP:13.11  size: 79560
# [libx264 @ 0x55e683229380] consecutive B-frames:  1.7%  0.0%  5.0% 93.3%
# [libx264 @ 0x55e683229380] mb I  I16..4: 10.7% 77.3% 11.9%
# [libx264 @ 0x55e683229380] mb P  I16..4:  1.6% 21.4%  4.8%  P16..4: 30.5% 22.2% 13.1%  0.0%  0.0%    skip: 6.5%
# [libx264 @ 0x55e683229380] mb B  I16..4:  0.3%  4.0%  1.1%  B16..8: 24.8% 14.3% 13.0%  direct:32.4%  skip:10.2%  L0:41.7% L1:31.4% BI:26.8%
# [libx264 @ 0x55e683229380] 8x8 transform intra:76.0% inter:93.8%
# [libx264 @ 0x55e683229380] coded y,uvDC,uvAC intra: 86.9% 70.8% 56.2% inter: 82.5% 82.1% 56.3%
# [libx264 @ 0x55e683229380] i16 v,h,dc,p: 68% 17%  6%  9%
# [libx264 @ 0x55e683229380] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu: 26% 20% 23%  3%  5%  6%  5%  5%  6%
# [libx264 @ 0x55e683229380] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 31% 21% 11%  5%  8%  7%  7%  5%  5%
# [libx264 @ 0x55e683229380] i8c dc,h,v,p: 43% 23% 27%  7%
# [libx264 @ 0x55e683229380] Weighted P-Frames: Y:26.7% UV:26.7%
# [libx264 @ 0x55e683229380] ref P L0: 35.3% 21.9% 19.4% 18.4%  4.9%
# [libx264 @ 0x55e683229380] ref B L0: 70.3% 24.5%  5.2%
# [libx264 @ 0x55e683229380] ref B L1: 86.4% 13.6%
# [libx264 @ 0x55e683229380] kb/s:4757.63
# ffmpeg version 4.4.2-0ubuntu0.22.04.1 Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 11 (Ubuntu 11.2.0-19ubuntu1)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.22.04.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libdav1d --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librabbitmq --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libsrt --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzimg --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-pocketsphinx --enable-librsvg --enable-libmfx --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared
#   libavutil      56. 70.100 / 56. 70.100
#   libavcodec     58.134.100 / 58.134.100
#   libavformat    58. 76.100 / 58. 76.100
#   libavdevice    58. 13.100 / 58. 13.100
#   libavfilter     7.110.100 /  7.110.100
#   libswscale      5.  9.100 /  5.  9.100
#   libswresample   3.  9.100 /  3.  9.100
#   libpostproc    55.  9.100 / 55.  9.100
# Input #0, image2, from '../../output/20240902/val_face_roll60_v2/3.0/both/1e-4/chk319/lightning_logs/version_0/video_frame/%03d.jpg':
#   Duration: 00:00:02.40, start: 0.000000, bitrate: N/A
#   Stream #0:0: Video: mjpeg (Baseline), yuvj420p(pc, bt470bg/unknown/unknown), 1034x776 [SAR 1:1 DAR 517:388], 25 fps, 25 tbr, 25 tbn, 25 tbc
# Stream mapping:
#   Stream #0:0 -> #0:0 (mjpeg (native) -> h264 (libx264))
# Press [q] to stop, [?] for help
# [swscaler @ 0x555593f3ea00] deprecated pixel format used, make sure you did set range correctly
# [libx264 @ 0x5555939f3380] using SAR=1/1
# [libx264 @ 0x5555939f3380] using cpu capabilities: MMX2 SSE2Fast SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2
# [libx264 @ 0x5555939f3380] profile High, level 3.1, 4:2:0, 8-bit
# [libx264 @ 0x5555939f3380] 264 - core 163 r3060 5db6aa6 - H.264/MPEG-4 AVC codec - Copyleft 2003-2021 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=-2 threads=24 lookahead_threads=4 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=6 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=crf mbtree=1 crf=12.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to '../../output/20240902/val_face_roll60_v2/3.0/both/1e-4/chk319/lightning_logs/version_0/video_grid.mp4.mp4':
#   Metadata:
#     encoder         : Lavf58.76.100
#   Stream #0:0: Video: h264 (avc1 / 0x31637661), yuv420p(tv, bt470bg/unknown/unknown, progressive), 1034x776 [SAR 1:1 DAR 517:388], q=2-31, 6 fps, 12288 tbn
#     Metadata:
#       encoder         : Lavc58.134.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: N/A
# frame=   60 fps= 39 q=-1.0 Lsize=    7500kB time=00:00:09.50 bitrate=6467.4kbits/s speed=6.11x
# video:7498kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.021749%
# [libx264 @ 0x5555939f3380] frame I:1     Avg QP:10.28  size:151497
# [libx264 @ 0x5555939f3380] frame P:15    Avg QP:11.71  size:159474
# [libx264 @ 0x5555939f3380] frame B:44    Avg QP:13.27  size:116684
# [libx264 @ 0x5555939f3380] consecutive B-frames:  1.7%  0.0%  5.0% 93.3%
# [libx264 @ 0x5555939f3380] mb I  I16..4:  9.2% 80.3% 10.6%
# [libx264 @ 0x5555939f3380] mb P  I16..4:  2.0% 51.4%  9.4%  P16..4: 14.8% 10.9%  5.6%  0.0%  0.0%    skip: 5.8%
# [libx264 @ 0x5555939f3380] mb B  I16..4:  1.0% 13.1%  5.1%  B16..8: 17.7% 11.3%  9.0%  direct:33.0%  skip: 9.9%  L0:38.6% L1:28.9% BI:32.5%
# [libx264 @ 0x5555939f3380] 8x8 transform intra:75.7% inter:95.3%
# [libx264 @ 0x5555939f3380] coded y,uvDC,uvAC intra: 90.7% 80.4% 65.4% inter: 81.4% 81.7% 63.2%
# [libx264 @ 0x5555939f3380] i16 v,h,dc,p: 55% 24%  9% 13%
# [libx264 @ 0x5555939f3380] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu: 27% 21% 15%  3%  6%  8%  6%  7%  6%
# [libx264 @ 0x5555939f3380] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 31% 23%  9%  5%  7%  7%  7%  6%  6%
# [libx264 @ 0x5555939f3380] i8c dc,h,v,p: 39% 24% 29%  8%
# [libx264 @ 0x5555939f3380] Weighted P-Frames: Y:33.3% UV:33.3%
# [libx264 @ 0x5555939f3380] ref P L0: 34.9% 19.5% 22.3% 16.8%  6.4%
# [libx264 @ 0x5555939f3380] ref B L0: 69.9% 24.7%  5.4%
# [libx264 @ 0x5555939f3380] ref B L1: 86.9% 13.1%
# [libx264 @ 0x5555939f3380] kb/s:6142.17
# ffmpeg version 4.4.2-0ubuntu0.22.04.1 Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 11 (Ubuntu 11.2.0-19ubuntu1)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.22.04.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libdav1d --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librabbitmq --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libsrt --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzimg --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-pocketsphinx --enable-librsvg --enable-libmfx --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared
#   libavutil      56. 70.100 / 56. 70.100
#   libavcodec     58.134.100 / 58.134.100
#   libavformat    58. 76.100 / 58. 76.100
#   libavdevice    58. 13.100 / 58. 13.100
#   libavfilter     7.110.100 /  7.110.100
#   libswscale      5.  9.100 /  5.  9.100
#   libswresample   3.  9.100 /  3.  9.100
#   libpostproc    55.  9.100 / 55.  9.100
# Input #0, image2, from '../../output/20240902/val_face_roll60_v2/5.0/both/1e-4/chk319/lightning_logs/version_0/video_frame/%03d.jpg':
#   Duration: 00:00:02.40, start: 0.000000, bitrate: N/A
#   Stream #0:0: Video: mjpeg (Baseline), yuvj420p(pc, bt470bg/unknown/unknown), 1034x776 [SAR 1:1 DAR 517:388], 25 fps, 25 tbr, 25 tbn, 25 tbc
# Stream mapping:
#   Stream #0:0 -> #0:0 (mjpeg (native) -> h264 (libx264))
# Press [q] to stop, [?] for help
# [swscaler @ 0x56411ebc3940] deprecated pixel format used, make sure you did set range correctly
# [libx264 @ 0x56411eba4380] using SAR=1/1
# [libx264 @ 0x56411eba4380] using cpu capabilities: MMX2 SSE2Fast SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2
# [libx264 @ 0x56411eba4380] profile High, level 3.1, 4:2:0, 8-bit
# [libx264 @ 0x56411eba4380] 264 - core 163 r3060 5db6aa6 - H.264/MPEG-4 AVC codec - Copyleft 2003-2021 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=-2 threads=24 lookahead_threads=4 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=6 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=crf mbtree=1 crf=12.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to '../../output/20240902/val_face_roll60_v2/5.0/both/1e-4/chk319/lightning_logs/version_0/video_grid.mp4.mp4':
#   Metadata:
#     encoder         : Lavf58.76.100
#   Stream #0:0: Video: h264 (avc1 / 0x31637661), yuv420p(tv, bt470bg/unknown/unknown, progressive), 1034x776 [SAR 1:1 DAR 517:388], q=2-31, 6 fps, 12288 tbn
#     Metadata:
#       encoder         : Lavc58.134.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: N/A
# frame=   60 fps= 40 q=-1.0 Lsize=    8358kB time=00:00:09.50 bitrate=7207.4kbits/s speed= 6.4x
# video:8357kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.019563%
# [libx264 @ 0x56411eba4380] frame I:1     Avg QP:11.24  size:148184
# [libx264 @ 0x56411eba4380] frame P:15    Avg QP:12.23  size:164473
# [libx264 @ 0x56411eba4380] frame B:44    Avg QP:13.44  size:135028
# [libx264 @ 0x56411eba4380] consecutive B-frames:  1.7%  0.0%  5.0% 93.3%
# [libx264 @ 0x56411eba4380] mb I  I16..4:  5.7% 83.8% 10.4%
# [libx264 @ 0x56411eba4380] mb P  I16..4:  2.4% 60.7% 11.3%  P16..4:  9.0%  6.9%  4.0%  0.0%  0.0%    skip: 5.9%
# [libx264 @ 0x56411eba4380] mb B  I16..4:  1.4% 19.0%  9.8%  B16..8: 13.4% 10.0%  8.2%  direct:28.5%  skip: 9.8%  L0:38.2% L1:28.0% BI:33.9%
# [libx264 @ 0x56411eba4380] 8x8 transform intra:71.9% inter:94.8%
# [libx264 @ 0x56411eba4380] coded y,uvDC,uvAC intra: 91.3% 83.1% 69.2% inter: 78.6% 79.1% 64.6%
# [libx264 @ 0x56411eba4380] i16 v,h,dc,p: 50% 27%  9% 15%
# [libx264 @ 0x56411eba4380] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu: 27% 21% 13%  4%  7%  8%  7%  7%  6%
# [libx264 @ 0x56411eba4380] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 30% 22%  8%  5%  7%  7%  7%  7%  6%
# [libx264 @ 0x56411eba4380] i8c dc,h,v,p: 39% 24% 29%  8%
# [libx264 @ 0x56411eba4380] Weighted P-Frames: Y:33.3% UV:33.3%
# [libx264 @ 0x56411eba4380] ref P L0: 34.4% 18.4% 24.0% 17.0%  6.3%
# [libx264 @ 0x56411eba4380] ref B L0: 70.5% 24.1%  5.4%
# [libx264 @ 0x56411eba4380] ref B L1: 87.0% 13.0%
# [libx264 @ 0x56411eba4380] kb/s:6845.19
# ffmpeg version 4.4.2-0ubuntu0.22.04.1 Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 11 (Ubuntu 11.2.0-19ubuntu1)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.22.04.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libdav1d --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librabbitmq --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libsrt --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzimg --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-pocketsphinx --enable-librsvg --enable-libmfx --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared
#   libavutil      56. 70.100 / 56. 70.100
#   libavcodec     58.134.100 / 58.134.100
#   libavformat    58. 76.100 / 58. 76.100
#   libavdevice    58. 13.100 / 58. 13.100
#   libavfilter     7.110.100 /  7.110.100
#   libswscale      5.  9.100 /  5.  9.100
#   libswresample   3.  9.100 /  3.  9.100
#   libpostproc    55.  9.100 / 55.  9.100
# Input #0, image2, from '../../output/20240902/val_face_roll60_v2/7.0/both/1e-4/chk319/lightning_logs/version_0/video_frame/%03d.jpg':
#   Duration: 00:00:02.40, start: 0.000000, bitrate: N/A
#   Stream #0:0: Video: mjpeg (Baseline), yuvj420p(pc, bt470bg/unknown/unknown), 1034x776 [SAR 1:1 DAR 517:388], 25 fps, 25 tbr, 25 tbn, 25 tbc
# Stream mapping:
#   Stream #0:0 -> #0:0 (mjpeg (native) -> h264 (libx264))
# Press [q] to stop, [?] for help
# [swscaler @ 0x56314e7650c0] deprecated pixel format used, make sure you did set range correctly
# [libx264 @ 0x56314e25a140] using SAR=1/1
# [libx264 @ 0x56314e25a140] using cpu capabilities: MMX2 SSE2Fast SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2
# [libx264 @ 0x56314e25a140] profile High, level 3.1, 4:2:0, 8-bit
# [libx264 @ 0x56314e25a140] 264 - core 163 r3060 5db6aa6 - H.264/MPEG-4 AVC codec - Copyleft 2003-2021 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=-2 threads=24 lookahead_threads=4 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=6 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=crf mbtree=1 crf=12.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to '../../output/20240902/val_face_roll60_v2/7.0/both/1e-4/chk319/lightning_logs/version_0/video_grid.mp4.mp4':
#   Metadata:
#     encoder         : Lavf58.76.100
#   Stream #0:0: Video: h264 (avc1 / 0x31637661), yuv420p(tv, bt470bg/unknown/unknown, progressive), 1034x776 [SAR 1:1 DAR 517:388], q=2-31, 6 fps, 12288 tbn
#     Metadata:
#       encoder         : Lavc58.134.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: N/A
# frame=   60 fps= 26 q=-1.0 Lsize=    9034kB time=00:00:09.50 bitrate=7790.2kbits/s speed=4.16x
# video:9032kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.017883%
# [libx264 @ 0x56314e25a140] frame I:1     Avg QP:11.18  size:156972
# [libx264 @ 0x56314e25a140] frame P:15    Avg QP:12.58  size:170590
# [libx264 @ 0x56314e25a140] frame B:44    Avg QP:13.62  size:148472
# [libx264 @ 0x56314e25a140] consecutive B-frames:  1.7%  0.0%  5.0% 93.3%
# [libx264 @ 0x56314e25a140] mb I  I16..4:  9.6% 79.5% 10.9%
# [libx264 @ 0x56314e25a140] mb P  I16..4:  2.4% 64.3% 12.0%  P16..4:  6.6%  5.4%  3.5%  0.0%  0.0%    skip: 5.9%
# [libx264 @ 0x56314e25a140] mb B  I16..4:  1.7% 21.9% 13.5%  B16..8: 11.0%  9.2%  7.9%  direct:25.0%  skip: 9.8%  L0:37.6% L1:28.4% BI:34.0%
# [libx264 @ 0x56314e25a140] 8x8 transform intra:68.9% inter:94.1%
# [libx264 @ 0x56314e25a140] coded y,uvDC,uvAC intra: 91.6% 85.3% 72.8% inter: 76.2% 76.7% 64.5%
# [libx264 @ 0x56314e25a140] i16 v,h,dc,p: 49% 29%  8% 14%
# [libx264 @ 0x56314e25a140] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu: 26% 21% 12%  4%  7%  8%  7%  8%  6%
# [libx264 @ 0x56314e25a140] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 28% 22%  8%  5%  8%  8%  8%  7%  7%
# [libx264 @ 0x56314e25a140] i8c dc,h,v,p: 39% 24% 28%  9%
# [libx264 @ 0x56314e25a140] Weighted P-Frames: Y:40.0% UV:40.0%
# [libx264 @ 0x56314e25a140] ref P L0: 35.2% 16.1% 25.7% 15.7%  7.4%
# [libx264 @ 0x56314e25a140] ref B L0: 70.9% 23.8%  5.3%
# [libx264 @ 0x56314e25a140] ref B L1: 87.2% 12.8%
# [libx264 @ 0x56314e25a140] kb/s:7398.86
# ffmpeg version 4.4.2-0ubuntu0.22.04.1 Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 11 (Ubuntu 11.2.0-19ubuntu1)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.22.04.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libdav1d --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librabbitmq --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libsrt --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzimg --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-pocketsphinx --enable-librsvg --enable-libmfx --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared
#   libavutil      56. 70.100 / 56. 70.100
#   libavcodec     58.134.100 / 58.134.100
#   libavformat    58. 76.100 / 58. 76.100
#   libavdevice    58. 13.100 / 58. 13.100
#   libavfilter     7.110.100 /  7.110.100
#   libswscale      5.  9.100 /  5.  9.100
#   libswresample   3.  9.100 /  3.  9.100
#   libpostproc    55.  9.100 / 55.  9.100
# Input #0, image2, from '../../output/20240902/val_face_roll60_v2/1.0/depth/1e-4/chk319/lightning_logs/version_0/video_frame/%03d.jpg':
#   Duration: 00:00:02.40, start: 0.000000, bitrate: N/A
#   Stream #0:0: Video: mjpeg (Baseline), yuvj420p(pc, bt470bg/unknown/unknown), 1034x776 [SAR 1:1 DAR 517:388], 25 fps, 25 tbr, 25 tbn, 25 tbc
# Stream mapping:
#   Stream #0:0 -> #0:0 (mjpeg (native) -> h264 (libx264))
# Press [q] to stop, [?] for help
# [swscaler @ 0x555e2a1002c0] deprecated pixel format used, make sure you did set range correctly
# [libx264 @ 0x555e2a0e1380] using SAR=1/1
# [libx264 @ 0x555e2a0e1380] using cpu capabilities: MMX2 SSE2Fast SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2
# [libx264 @ 0x555e2a0e1380] profile High, level 3.1, 4:2:0, 8-bit
# [libx264 @ 0x555e2a0e1380] 264 - core 163 r3060 5db6aa6 - H.264/MPEG-4 AVC codec - Copyleft 2003-2021 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=-2 threads=24 lookahead_threads=4 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=6 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=crf mbtree=1 crf=12.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to '../../output/20240902/val_face_roll60_v2/1.0/depth/1e-4/chk319/lightning_logs/version_0/video_grid.mp4.mp4':
#   Metadata:
#     encoder         : Lavf58.76.100
#   Stream #0:0: Video: h264 (avc1 / 0x31637661), yuv420p(tv, bt470bg/unknown/unknown, progressive), 1034x776 [SAR 1:1 DAR 517:388], q=2-31, 6 fps, 12288 tbn
#     Metadata:
#       encoder         : Lavc58.134.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: N/A
# frame=   60 fps= 39 q=-1.0 Lsize=    6211kB time=00:00:09.50 bitrate=5355.8kbits/s speed=6.24x
# video:6209kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.026013%
# [libx264 @ 0x555e2a0e1380] frame I:1     Avg QP: 9.13  size:184256
# [libx264 @ 0x555e2a0e1380] frame P:15    Avg QP:10.27  size:152926
# [libx264 @ 0x555e2a0e1380] frame B:44    Avg QP:13.07  size: 88171
# [libx264 @ 0x555e2a0e1380] consecutive B-frames:  1.7%  0.0%  5.0% 93.3%
# [libx264 @ 0x555e2a0e1380] mb I  I16..4:  9.0% 79.9% 11.1%
# [libx264 @ 0x555e2a0e1380] mb P  I16..4:  2.2% 28.3%  6.1%  P16..4: 26.5% 19.9% 11.0%  0.0%  0.0%    skip: 5.9%
# [libx264 @ 0x555e2a0e1380] mb B  I16..4:  0.4%  5.2%  1.5%  B16..8: 23.8% 14.0% 11.8%  direct:33.2%  skip:10.1%  L0:40.2% L1:30.4% BI:29.4%
# [libx264 @ 0x555e2a0e1380] 8x8 transform intra:76.4% inter:94.3%
# [libx264 @ 0x555e2a0e1380] coded y,uvDC,uvAC intra: 88.2% 74.2% 59.7% inter: 82.9% 82.5% 58.3%
# [libx264 @ 0x555e2a0e1380] i16 v,h,dc,p: 74% 15%  5%  6%
# [libx264 @ 0x555e2a0e1380] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu: 27% 20% 21%  3%  5%  7%  5%  6%  6%
# [libx264 @ 0x555e2a0e1380] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 31% 21% 11%  5%  8%  7%  7%  6%  6%
# [libx264 @ 0x555e2a0e1380] i8c dc,h,v,p: 42% 23% 28%  7%
# [libx264 @ 0x555e2a0e1380] Weighted P-Frames: Y:40.0% UV:40.0%
# [libx264 @ 0x555e2a0e1380] ref P L0: 33.5% 20.9% 19.8% 18.4%  7.4%
# [libx264 @ 0x555e2a0e1380] ref B L0: 69.2% 25.1%  5.7%
# [libx264 @ 0x555e2a0e1380] ref B L1: 87.0% 13.0%
# [libx264 @ 0x555e2a0e1380] kb/s:5086.13
# ffmpeg version 4.4.2-0ubuntu0.22.04.1 Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 11 (Ubuntu 11.2.0-19ubuntu1)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.22.04.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libdav1d --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librabbitmq --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libsrt --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzimg --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-pocketsphinx --enable-librsvg --enable-libmfx --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared
#   libavutil      56. 70.100 / 56. 70.100
#   libavcodec     58.134.100 / 58.134.100
#   libavformat    58. 76.100 / 58. 76.100
#   libavdevice    58. 13.100 / 58. 13.100
#   libavfilter     7.110.100 /  7.110.100
#   libswscale      5.  9.100 /  5.  9.100
#   libswresample   3.  9.100 /  3.  9.100
#   libpostproc    55.  9.100 / 55.  9.100
# Input #0, image2, from '../../output/20240902/val_face_roll60_v2/3.0/depth/1e-4/chk319/lightning_logs/version_0/video_frame/%03d.jpg':
#   Duration: 00:00:02.40, start: 0.000000, bitrate: N/A
#   Stream #0:0: Video: mjpeg (Baseline), yuvj420p(pc, bt470bg/unknown/unknown), 1034x776 [SAR 1:1 DAR 517:388], 25 fps, 25 tbr, 25 tbn, 25 tbc
# Stream mapping:
#   Stream #0:0 -> #0:0 (mjpeg (native) -> h264 (libx264))
# Press [q] to stop, [?] for help
# [swscaler @ 0x560247056dc0] deprecated pixel format used, make sure you did set range correctly
# [libx264 @ 0x560246b4c380] using SAR=1/1
# [libx264 @ 0x560246b4c380] using cpu capabilities: MMX2 SSE2Fast SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2
# [libx264 @ 0x560246b4c380] profile High, level 3.1, 4:2:0, 8-bit
# [libx264 @ 0x560246b4c380] 264 - core 163 r3060 5db6aa6 - H.264/MPEG-4 AVC codec - Copyleft 2003-2021 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=-2 threads=24 lookahead_threads=4 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=6 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=crf mbtree=1 crf=12.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to '../../output/20240902/val_face_roll60_v2/3.0/depth/1e-4/chk319/lightning_logs/version_0/video_grid.mp4.mp4':
#   Metadata:
#     encoder         : Lavf58.76.100
#   Stream #0:0: Video: h264 (avc1 / 0x31637661), yuv420p(tv, bt470bg/unknown/unknown, progressive), 1034x776 [SAR 1:1 DAR 517:388], q=2-31, 6 fps, 12288 tbn
#     Metadata:
#       encoder         : Lavc58.134.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: N/A
# frame=   60 fps= 12 q=-1.0 Lsize=    7803kB time=00:00:09.50 bitrate=6728.8kbits/s speed=1.84x
# video:7802kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.020654%
# [libx264 @ 0x560246b4c380] frame I:1     Avg QP:10.91  size:147667
# [libx264 @ 0x560246b4c380] frame P:15    Avg QP:11.86  size:159327
# [libx264 @ 0x560246b4c380] frame B:44    Avg QP:13.23  size:123877
# [libx264 @ 0x560246b4c380] consecutive B-frames:  1.7%  0.0%  5.0% 93.3%
# [libx264 @ 0x560246b4c380] mb I  I16..4:  3.9% 86.0% 10.1%
# [libx264 @ 0x560246b4c380] mb P  I16..4:  2.3% 56.5% 10.2%  P16..4: 11.6%  8.8%  4.9%  0.0%  0.0%    skip: 5.7%
# [libx264 @ 0x560246b4c380] mb B  I16..4:  1.2% 16.3%  7.2%  B16..8: 15.1% 11.0%  8.7%  direct:30.5%  skip: 9.9%  L0:38.9% L1:27.7% BI:33.4%
# [libx264 @ 0x560246b4c380] 8x8 transform intra:74.3% inter:95.0%
# [libx264 @ 0x560246b4c380] coded y,uvDC,uvAC intra: 90.8% 80.7% 66.7% inter: 79.7% 80.2% 63.5%
# [libx264 @ 0x560246b4c380] i16 v,h,dc,p: 55% 25%  9% 11%
# [libx264 @ 0x560246b4c380] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu: 26% 21% 16%  3%  6%  8%  6%  7%  6%
# [libx264 @ 0x560246b4c380] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 30% 22%  9%  5%  7%  8%  7%  6%  6%
# [libx264 @ 0x560246b4c380] i8c dc,h,v,p: 38% 24% 30%  8%
# [libx264 @ 0x560246b4c380] Weighted P-Frames: Y:40.0% UV:40.0%
# [libx264 @ 0x560246b4c380] ref P L0: 34.3% 18.8% 22.6% 16.9%  7.4%
# [libx264 @ 0x560246b4c380] ref B L0: 70.4% 24.2%  5.4%
# [libx264 @ 0x560246b4c380] ref B L1: 86.8% 13.2%
# [libx264 @ 0x560246b4c380] kb/s:6390.53
# ffmpeg version 4.4.2-0ubuntu0.22.04.1 Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 11 (Ubuntu 11.2.0-19ubuntu1)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.22.04.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libdav1d --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librabbitmq --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libsrt --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzimg --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-pocketsphinx --enable-librsvg --enable-libmfx --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared
#   libavutil      56. 70.100 / 56. 70.100
#   libavcodec     58.134.100 / 58.134.100
#   libavformat    58. 76.100 / 58. 76.100
#   libavdevice    58. 13.100 / 58. 13.100
#   libavfilter     7.110.100 /  7.110.100
#   libswscale      5.  9.100 /  5.  9.100
#   libswresample   3.  9.100 /  3.  9.100
#   libpostproc    55.  9.100 / 55.  9.100
# Input #0, image2, from '../../output/20240902/val_face_roll60_v2/5.0/depth/1e-4/chk319/lightning_logs/version_0/video_frame/%03d.jpg':
#   Duration: 00:00:02.40, start: 0.000000, bitrate: N/A
#   Stream #0:0: Video: mjpeg (Baseline), yuvj420p(pc, bt470bg/unknown/unknown), 1034x776 [SAR 1:1 DAR 517:388], 25 fps, 25 tbr, 25 tbn, 25 tbc
# Stream mapping:
#   Stream #0:0 -> #0:0 (mjpeg (native) -> h264 (libx264))
# Press [q] to stop, [?] for help
# [swscaler @ 0x5590c41483c0] deprecated pixel format used, make sure you did set range correctly
# [libx264 @ 0x5590c3bf8380] using SAR=1/1
# [libx264 @ 0x5590c3bf8380] using cpu capabilities: MMX2 SSE2Fast SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2
# [libx264 @ 0x5590c3bf8380] profile High, level 3.1, 4:2:0, 8-bit
# [libx264 @ 0x5590c3bf8380] 264 - core 163 r3060 5db6aa6 - H.264/MPEG-4 AVC codec - Copyleft 2003-2021 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=-2 threads=24 lookahead_threads=4 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=6 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=crf mbtree=1 crf=12.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to '../../output/20240902/val_face_roll60_v2/5.0/depth/1e-4/chk319/lightning_logs/version_0/video_grid.mp4.mp4':
#   Metadata:
#     encoder         : Lavf58.76.100
#   Stream #0:0: Video: h264 (avc1 / 0x31637661), yuv420p(tv, bt470bg/unknown/unknown, progressive), 1034x776 [SAR 1:1 DAR 517:388], q=2-31, 6 fps, 12288 tbn
#     Metadata:
#       encoder         : Lavc58.134.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: N/A
# frame=   60 fps= 45 q=-1.0 Lsize=    8582kB time=00:00:09.50 bitrate=7400.5kbits/s speed=7.11x
# video:8581kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.019052%
# [libx264 @ 0x5590c3bf8380] frame I:1     Avg QP:11.59  size:146807
# [libx264 @ 0x5590c3bf8380] frame P:15    Avg QP:12.38  size:163566
# [libx264 @ 0x5590c3bf8380] frame B:44    Avg QP:13.42  size:140580
# [libx264 @ 0x5590c3bf8380] consecutive B-frames:  1.7%  0.0%  5.0% 93.3%
# [libx264 @ 0x5590c3bf8380] mb I  I16..4:  5.9% 83.7% 10.4%
# [libx264 @ 0x5590c3bf8380] mb P  I16..4:  2.5% 62.9% 11.7%  P16..4:  7.4%  5.8%  3.8%  0.0%  0.0%    skip: 5.8%
# [libx264 @ 0x5590c3bf8380] mb B  I16..4:  1.8% 22.6% 12.8%  B16..8: 10.6%  9.5%  8.1%  direct:24.7%  skip: 9.9%  L0:38.9% L1:27.7% BI:33.4%
# [libx264 @ 0x5590c3bf8380] 8x8 transform intra:69.9% inter:94.0%
# [libx264 @ 0x5590c3bf8380] coded y,uvDC,uvAC intra: 91.3% 83.1% 70.2% inter: 75.9% 76.6% 63.5%
# [libx264 @ 0x5590c3bf8380] i16 v,h,dc,p: 52% 27% 10% 11%
# [libx264 @ 0x5590c3bf8380] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu: 26% 20% 13%  4%  7%  9%  7%  8%  6%
# [libx264 @ 0x5590c3bf8380] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 28% 22%  8%  5%  8%  8%  7%  7%  7%
# [libx264 @ 0x5590c3bf8380] i8c dc,h,v,p: 38% 24% 29%  9%
# [libx264 @ 0x5590c3bf8380] Weighted P-Frames: Y:33.3% UV:33.3%
# [libx264 @ 0x5590c3bf8380] ref P L0: 36.0% 16.4% 25.0% 17.1%  5.5%
# [libx264 @ 0x5590c3bf8380] ref B L0: 70.3% 24.0%  5.7%
# [libx264 @ 0x5590c3bf8380] ref B L1: 86.8% 13.2%
# [libx264 @ 0x5590c3bf8380] kb/s:7028.67
# ffmpeg version 4.4.2-0ubuntu0.22.04.1 Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 11 (Ubuntu 11.2.0-19ubuntu1)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.22.04.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libdav1d --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librabbitmq --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libsrt --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzimg --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-pocketsphinx --enable-librsvg --enable-libmfx --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared
#   libavutil      56. 70.100 / 56. 70.100
#   libavcodec     58.134.100 / 58.134.100
#   libavformat    58. 76.100 / 58. 76.100
#   libavdevice    58. 13.100 / 58. 13.100
#   libavfilter     7.110.100 /  7.110.100
#   libswscale      5.  9.100 /  5.  9.100
#   libswresample   3.  9.100 /  3.  9.100
#   libpostproc    55.  9.100 / 55.  9.100
# Input #0, image2, from '../../output/20240902/val_face_roll60_v2/7.0/depth/1e-4/chk319/lightning_logs/version_0/video_frame/%03d.jpg':
#   Duration: 00:00:02.40, start: 0.000000, bitrate: N/A
#   Stream #0:0: Video: mjpeg (Baseline), yuvj420p(pc, bt470bg/unknown/unknown), 1034x776 [SAR 1:1 DAR 517:388], 25 fps, 25 tbr, 25 tbn, 25 tbc
# Stream mapping:
#   Stream #0:0 -> #0:0 (mjpeg (native) -> h264 (libx264))
# Press [q] to stop, [?] for help
# [swscaler @ 0x55ea5f551f40] deprecated pixel format used, make sure you did set range correctly
# [libx264 @ 0x55ea5f085140] using SAR=1/1
# [libx264 @ 0x55ea5f085140] using cpu capabilities: MMX2 SSE2Fast SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2
# [libx264 @ 0x55ea5f085140] profile High, level 3.1, 4:2:0, 8-bit
# [libx264 @ 0x55ea5f085140] 264 - core 163 r3060 5db6aa6 - H.264/MPEG-4 AVC codec - Copyleft 2003-2021 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=-2 threads=24 lookahead_threads=4 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=6 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=crf mbtree=1 crf=12.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to '../../output/20240902/val_face_roll60_v2/7.0/depth/1e-4/chk319/lightning_logs/version_0/video_grid.mp4.mp4':
#   Metadata:
#     encoder         : Lavf58.76.100
#   Stream #0:0: Video: h264 (avc1 / 0x31637661), yuv420p(tv, bt470bg/unknown/unknown, progressive), 1034x776 [SAR 1:1 DAR 517:388], q=2-31, 6 fps, 12288 tbn
#     Metadata:
#       encoder         : Lavc58.134.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: N/A
# frame=   60 fps= 44 q=-1.0 Lsize=    9229kB time=00:00:09.50 bitrate=7958.6kbits/s speed=6.93x
# video:9228kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.017504%
# [libx264 @ 0x55ea5f085140] frame I:1     Avg QP:12.00  size:151822
# [libx264 @ 0x55ea5f085140] frame P:15    Avg QP:12.63  size:170159
# [libx264 @ 0x55ea5f085140] frame B:44    Avg QP:13.68  size:153281
# [libx264 @ 0x55ea5f085140] consecutive B-frames:  1.7%  0.0%  5.0% 93.3%
# [libx264 @ 0x55ea5f085140] mb I  I16..4:  4.7% 84.9% 10.4%
# [libx264 @ 0x55ea5f085140] mb P  I16..4:  2.8% 65.5% 12.4%  P16..4:  5.7%  4.6%  3.2%  0.0%  0.0%    skip: 5.8%
# [libx264 @ 0x55ea5f085140] mb B  I16..4:  2.0% 25.7% 16.9%  B16..8:  8.6%  8.7%  7.7%  direct:20.4%  skip: 9.9%  L0:39.0% L1:27.9% BI:33.2%
# [libx264 @ 0x55ea5f085140] 8x8 transform intra:67.2% inter:92.7%
# [libx264 @ 0x55ea5f085140] coded y,uvDC,uvAC intra: 91.6% 85.4% 73.7% inter: 72.7% 73.4% 62.5%
# [libx264 @ 0x55ea5f085140] i16 v,h,dc,p: 49% 27% 11% 13%
# [libx264 @ 0x55ea5f085140] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu: 26% 20% 12%  4%  7%  9%  7%  8%  6%
# [libx264 @ 0x55ea5f085140] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 27% 21%  8%  6%  8%  9%  7%  8%  7%
# [libx264 @ 0x55ea5f085140] i8c dc,h,v,p: 38% 23% 29% 10%
# [libx264 @ 0x55ea5f085140] Weighted P-Frames: Y:33.3% UV:33.3%
# [libx264 @ 0x55ea5f085140] ref P L0: 36.2% 14.7% 26.5% 17.0%  5.6%
# [libx264 @ 0x55ea5f085140] ref B L0: 70.7% 23.8%  5.5%
# [libx264 @ 0x55ea5f085140] ref B L1: 86.4% 13.6%
# [libx264 @ 0x55ea5f085140] kb/s:7558.85
